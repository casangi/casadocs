# %% [markdown]
# <a href="https://colab.research.google.com/github/casangi/casadocs/blob/CAS-14318/docs/notebooks/XML561.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # XML information CASA 5.6.1
#
# - [accor 		 ](../tasks561/accor.xml.rst		 )
# - [accum 		 ](../tasks561/accum.xml.rst		 )
# - [apparentsens 	 ](../tasks561/apparentsens.xml.rst	 )
# - [applycal 	 ](../tasks561/applycal.xml.rst	 )
# - [asdmsummary 	 ](../tasks561/asdmsummary.xml.rst	 )
# - [bandpass 	 ](../tasks561/bandpass.xml.rst	 )
# - [blcal 		 ](../tasks561/blcal.xml.rst		 )
# - [browsetable 	 ](../tasks561/browsetable.xml.rst	 )
# - [calstat 	 ](../tasks561/calstat.xml.rst		 )
# - [caltabconvert 	 ](../tasks561/caltabconvert.xml.rst	 )
# - [clean 		 ](../tasks561/clean.xml.rst		 )
# - [clearcal 	 ](../tasks561/clearcal.xml.rst	 )
# - [clearstat 	 ](../tasks561/clearstat.xml.rst	 )
# - [concat 		 ](../tasks561/concat.xml.rst		 )
# - [conjugatevis 	 ](../tasks561/conjugatevis.xml.rst	 )
# - [cvel 		 ](../tasks561/cvel.xml.rst		 )
# - [cvel2 		 ](../tasks561/cvel2.xml.rst		 )
# - [deconvolve 	 ](../tasks561/deconvolve.xml.rst	 )
# - [delmod 		 ](../tasks561/delmod.xml.rst		 )
# - [exportasdm 	 ](../tasks561/exportasdm.xml.rst	 )
# - [exportfits 	 ](../tasks561/exportfits.xml.rst	 )
# - [exportuvfits 	 ](../tasks561/exportuvfits.xml.rst	 )
# - [feather 	 ](../tasks561/feather.xml.rst		 )
# - [fixplanets 	 ](../tasks561/fixplanets.xml.rst	 )
# - [fixvis 		 ](../tasks561/fixvis.xml.rst		 )
# - [flagcmd 	 ](../tasks561/flagcmd.xml.rst		 )
# - [flagdata 	 ](../tasks561/flagdata.xml.rst	 )
# - [flagmanager 	 ](../tasks561/flagmanager.xml.rst	 )
# - [fluxscale 	 ](../tasks561/fluxscale.xml.rst	 )
# - [fringefit 	 ](../tasks561/fringefit.xml.rst	 )
# - [ft 		 ](../tasks561/ft.xml.rst		 )
# - [gaincal 	 ](../tasks561/gaincal.xml.rst		 )
# - [gencal 		 ](../tasks561/gencal.xml.rst		 )
# - [hanningsmooth 	 ](../tasks561/hanningsmooth.xml.rst	 )
# - [imcollapse 	 ](../tasks561/imcollapse.xml.rst	 )
# - [imcontsub 	 ](../tasks561/imcontsub.xml.rst	 )
# - [imdev 		 ](../tasks561/imdev.xml.rst		 )
# - [imfit 		 ](../tasks561/imfit.xml.rst		 )
# - [imhead 		 ](../tasks561/imhead.xml.rst		 )
# - [imhistory 	 ](../tasks561/imhistory.xml.rst	 )
# - [immath 		 ](../tasks561/immath.xml.rst		 )
# - [immoments 	 ](../tasks561/immoments.xml.rst	 )
# - [impbcor 	 ](../tasks561/impbcor.xml.rst		 )
# - [importasap 	 ](../tasks561/importasap.xml.rst	 )
# - [importasdm 	 ](../tasks561/importasdm.xml.rst	 )
# - [importatca 	 ](../tasks561/importatca.xml.rst	 )
# - [importfits 	 ](../tasks561/importfits.xml.rst	 )
# - [importfitsidi 	 ](../tasks561/importfitsidi.xml.rst	 )
# - [importgmrt 	 ](../tasks561/importgmrt.xml.rst	 )
# - [importmiriad 	 ](../tasks561/importmiriad.xml.rst	 )
# - [importnro 	 ](../tasks561/importnro.xml.rst	 )
# - [importuvfits 	 ](../tasks561/importuvfits.xml.rst	 )
# - [importvla 	 ](../tasks561/importvla.xml.rst	 )
# - [impv 		 ](../tasks561/impv.xml.rst		 )
# - [imrebin 	 ](../tasks561/imrebin.xml.rst		 )
# - [imreframe 	 ](../tasks561/imreframe.xml.rst	 )
# - [imregrid 	 ](../tasks561/imregrid.xml.rst	 )
# - [imsmooth 	 ](../tasks561/imsmooth.xml.rst	 )
# - [imstat 		 ](../tasks561/imstat.xml.rst		 )
# - [imsubimage 	 ](../tasks561/imsubimage.xml.rst	 )
# - [imtrans 	 ](../tasks561/imtrans.xml.rst		 )
# - [imval 		 ](../tasks561/imval.xml.rst		 )
# - [imview 		 ](../tasks561/imview.xml.rst		 )
# - [initweights 	 ](../tasks561/initweights.xml.rst	 )
# - [listcal 	 ](../tasks561/listcal.xml.rst		 )
# - [listfits 	 ](../tasks561/listfits.xml.rst	 )
# - [listhistory 	 ](../tasks561/listhistory.xml.rst	 )
# - [listobs 	 ](../tasks561/listobs.xml.rst		 )
# - [listpartition 	 ](../tasks561/listpartition.xml.rst	 )
# - [listsdm 	 ](../tasks561/listsdm.xml.rst		 )
# - [listvis 	 ](../tasks561/listvis.xml.rst		 )
# - [makemask 	 ](../tasks561/makemask.xml.rst	 )
# - [mstransform 	 ](../tasks561/mstransform.xml.rst	 )
# - [msuvbin 	 ](../tasks561/msuvbin.xml.rst		 )
# - [msview 		 ](../tasks561/msview.xml.rst		 )
# - [nrobeamaverage 	 ](../tasks561/nrobeamaverage.xml.rst	 )
# - [oldsplit 	 ](../tasks561/oldsplit.xml.rst	 )
# - [oldstatwt 	 ](../tasks561/oldstatwt.xml.rst	 )
# - [partition 	 ](../tasks561/partition.xml.rst	 )
# - [plotants 	 ](../tasks561/plotants.xml.rst	 )
# - [plotbandpass 	 ](../tasks561/plotbandpass.xml.rst	 )
# - [plotcal 	 ](../tasks561/plotcal.xml.rst		 )
# - [plotms 		 ](../tasks561/plotms.xml.rst		 )
# - [plotprofilemap 	 ](../tasks561/plotprofilemap.xml.rst	 )
# - [plotweather 	 ](../tasks561/plotweather.xml.rst	 )
# - [polcal 		 ](../tasks561/polcal.xml.rst		 )
# - [polfromgain 	 ](../tasks561/polfromgain.xml.rst	 )
# - [predictcomp 	 ](../tasks561/predictcomp.xml.rst	 )
# - [rerefant 	 ](../tasks561/rerefant.xml.rst	 )
# - [rmfit 		 ](../tasks561/rmfit.xml.rst		 )
# - [rmtables 	 ](../tasks561/rmtables.xml.rst	 )
# - [sdbaseline 	 ](../tasks561/sdbaseline.xml.rst	 )
# - [sdcal 		 ](../tasks561/sdcal.xml.rst		 )
# - [sdfit 		 ](../tasks561/sdfit.xml.rst		 )
# - [sdfixscan 	 ](../tasks561/sdfixscan.xml.rst	 )
# - [sdgaincal 	 ](../tasks561/sdgaincal.xml.rst	 )
# - [sdimaging 	 ](../tasks561/sdimaging.xml.rst	 )
# - [sdintimaging 	 ](../tasks561/sdintimaging.xml.rst	 )
# - [sdpolaverage 	 ](../tasks561/sdpolaverage.xml.rst	 )
# - [sdsidebandsplit  ](../tasks561/sdsidebandsplit.xml.rst	 )
# - [sdsmooth 	 ](../tasks561/sdsmooth.xml.rst	 )
# - [sdtimeaverage 	 ](../tasks561/sdtimeaverage.xml.rst	 )
# - [setjy 		 ](../tasks561/setjy.xml.rst		 )
# - [simalma 	 ](../tasks561/simalma.xml.rst		 )
# - [simanalyze 	 ](../tasks561/simanalyze.xml.rst	 )
# - [simobserve 	 ](../tasks561/simobserve.xml.rst	 )
# - [slsearch 	 ](../tasks561/slsearch.xml.rst	 )
# - [smoothcal 	 ](../tasks561/smoothcal.xml.rst	 )
# - [specfit 	 ](../tasks561/specfit.xml.rst		 )
# - [specflux 	 ](../tasks561/specflux.xml.rst	 )
# - [specsmooth 	 ](../tasks561/specsmooth.xml.rst	 )
# - [splattotable 	 ](../tasks561/splattotable.xml.rst	 )
# - [split 		 ](../tasks561/split.xml.rst		 )
# - [spxfit 		 ](../tasks561/spxfit.xml.rst		 )
# - [statwt 		 ](../tasks561/statwt.xml.rst		 )
# - [tclean 		 ](../tasks561/tclean.xml.rst		 )
# - [tclean2 	 ](../tasks561/tclean2.xml.rst		 )
# - [testconcat 	 ](../tasks561/testconcat.xml.rst	 )
# - [tsdimaging 	 ](../tasks561/tsdimaging.xml.rst	 )
# - [uvcontsub 	 ](../tasks561/uvcontsub.xml.rst	 )
# - [uvcontsub3 	 ](../tasks561/uvcontsub3.xml.rst	 )
# - [uvmodelfit 	 ](../tasks561/uvmodelfit.xml.rst	 )
# - [uvsub 		 ](../tasks561/uvsub.xml.rst		 )
# - [viewer 		 ](../tasks561/viewer.xml.rst		 )
# - [virtualconcat 	 ](../tasks561/virtualconcat.xml.rst	 )
# - [vishead 	 ](../tasks561/vishead.xml.rst		 )
# - [visstat 	 ](../tasks561/visstat.xml.rst		 )
# - [widebandpbcor 	 ](../tasks561/widebandpbcor.xml.rst	 )
# - [wvrgcal          ](../tasks561/wvrgcal.xml.rst          )
#
# ## Download
#
# Original XML files 5.6.1: [download here](https://drive.google.com/file/d/1MdMEvx1-6TQ27PkqH_10pZfa7rOpcKmz/view?usp=drive_link)
