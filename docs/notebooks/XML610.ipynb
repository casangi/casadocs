# %% [markdown]
# <a href="https://colab.research.google.com/github/casangi/casadocs/blob/CAS-14318/docs/notebooks/XML610.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # XML information CASA 5.7.0/6.1.0
#
# - [accor 		 ](../tasks610/accor.xml.rst		 )
# - [accum 		 ](../tasks610/accum.xml.rst		 )
# - [apparentsens 	 ](../tasks610/apparentsens.xml.rst	 )
# - [applycal 	 ](../tasks610/applycal.xml.rst	 )
# - [asdmsummary 	 ](../tasks610/asdmsummary.xml.rst	 )
# - [bandpass 	 ](../tasks610/bandpass.xml.rst	 )
# - [blcal 		 ](../tasks610/blcal.xml.rst		 )
# - [browsetable 	 ](../tasks610/browsetable.xml.rst	 )
# - [calstat 	 ](../tasks610/calstat.xml.rst		 )
# - [caltabconvert 	 ](../tasks610/caltabconvert.xml.rst	 )
# - [clean 		 ](../tasks610/clean.xml.rst		 )
# - [clearcal 	 ](../tasks610/clearcal.xml.rst	 )
# - [clearstat 	 ](../tasks610/clearstat.xml.rst	 )
# - [concat 		 ](../tasks610/concat.xml.rst		 )
# - [conjugatevis 	 ](../tasks610/conjugatevis.xml.rst	 )
# - [cvel 		 ](../tasks610/cvel.xml.rst		 )
# - [cvel2 		 ](../tasks610/cvel2.xml.rst		 )
# - [deconvolve 	 ](../tasks610/deconvolve.xml.rst	 )
# - [delmod 		 ](../tasks610/delmod.xml.rst		 )
# - [exportasdm 	 ](../tasks610/exportasdm.xml.rst	 )
# - [exportfits 	 ](../tasks610/exportfits.xml.rst	 )
# - [exportuvfits 	 ](../tasks610/exportuvfits.xml.rst	 )
# - [feather 	 ](../tasks610/feather.xml.rst		 )
# - [fixplanets 	 ](../tasks610/fixplanets.xml.rst	 )
# - [fixvis 		 ](../tasks610/fixvis.xml.rst		 )
# - [flagcmd 	 ](../tasks610/flagcmd.xml.rst		 )
# - [flagdata 	 ](../tasks610/flagdata.xml.rst	 )
# - [flagmanager 	 ](../tasks610/flagmanager.xml.rst	 )
# - [fluxscale 	 ](../tasks610/fluxscale.xml.rst	 )
# - [fringefit 	 ](../tasks610/fringefit.xml.rst	 )
# - [ft 		 ](../tasks610/ft.xml.rst		 )
# - [gaincal 	 ](../tasks610/gaincal.xml.rst		 )
# - [gencal 		 ](../tasks610/gencal.xml.rst		 )
# - [hanningsmooth 	 ](../tasks610/hanningsmooth.xml.rst	 )
# - [imcollapse 	 ](../tasks610/imcollapse.xml.rst	 )
# - [imcontsub 	 ](../tasks610/imcontsub.xml.rst	 )
# - [imdev 		 ](../tasks610/imdev.xml.rst		 )
# - [imfit 		 ](../tasks610/imfit.xml.rst		 )
# - [imhead 		 ](../tasks610/imhead.xml.rst		 )
# - [imhistory 	 ](../tasks610/imhistory.xml.rst	 )
# - [immath 		 ](../tasks610/immath.xml.rst		 )
# - [immoments 	 ](../tasks610/immoments.xml.rst	 )
# - [impbcor 	 ](../tasks610/impbcor.xml.rst		 )
# - [importasap 	 ](../tasks610/importasap.xml.rst	 )
# - [importasdm 	 ](../tasks610/importasdm.xml.rst	 )
# - [importatca 	 ](../tasks610/importatca.xml.rst	 )
# - [importfits 	 ](../tasks610/importfits.xml.rst	 )
# - [importfitsidi 	 ](../tasks610/importfitsidi.xml.rst	 )
# - [importgmrt 	 ](../tasks610/importgmrt.xml.rst	 )
# - [importmiriad 	 ](../tasks610/importmiriad.xml.rst	 )
# - [importnro 	 ](../tasks610/importnro.xml.rst	 )
# - [importuvfits 	 ](../tasks610/importuvfits.xml.rst	 )
# - [importvla 	 ](../tasks610/importvla.xml.rst	 )
# - [impv 		 ](../tasks610/impv.xml.rst		 )
# - [imrebin 	 ](../tasks610/imrebin.xml.rst		 )
# - [imreframe 	 ](../tasks610/imreframe.xml.rst	 )
# - [imregrid 	 ](../tasks610/imregrid.xml.rst	 )
# - [imsmooth 	 ](../tasks610/imsmooth.xml.rst	 )
# - [imstat 		 ](../tasks610/imstat.xml.rst		 )
# - [imsubimage 	 ](../tasks610/imsubimage.xml.rst	 )
# - [imtrans 	 ](../tasks610/imtrans.xml.rst		 )
# - [imval 		 ](../tasks610/imval.xml.rst		 )
# - [imview 		 ](../tasks610/imview.xml.rst		 )
# - [initweights 	 ](../tasks610/initweights.xml.rst	 )
# - [listcal 	 ](../tasks610/listcal.xml.rst		 )
# - [listfits 	 ](../tasks610/listfits.xml.rst	 )
# - [listhistory 	 ](../tasks610/listhistory.xml.rst	 )
# - [listobs 	 ](../tasks610/listobs.xml.rst		 )
# - [listpartition 	 ](../tasks610/listpartition.xml.rst	 )
# - [listsdm 	 ](../tasks610/listsdm.xml.rst		 )
# - [listvis 	 ](../tasks610/listvis.xml.rst		 )
# - [makemask 	 ](../tasks610/makemask.xml.rst	 )
# - [mstransform 	 ](../tasks610/mstransform.xml.rst	 )
# - [msuvbin 	 ](../tasks610/msuvbin.xml.rst		 )
# - [msview 		 ](../tasks610/msview.xml.rst		 )
# - [nrobeamaverage 	 ](../tasks610/nrobeamaverage.xml.rst	 )
# - [oldsplit 	 ](../tasks610/oldsplit.xml.rst	 )
# - [oldstatwt 	 ](../tasks610/oldstatwt.xml.rst	 )
# - [partition 	 ](../tasks610/partition.xml.rst	 )
# - [plotants 	 ](../tasks610/plotants.xml.rst	 )
# - [plotbandpass 	 ](../tasks610/plotbandpass.xml.rst	 )
# - [plotcal 	 ](../tasks610/plotcal.xml.rst		 )
# - [plotms 		 ](../tasks610/plotms.xml.rst		 )
# - [plotprofilemap 	 ](../tasks610/plotprofilemap.xml.rst	 )
# - [plotweather 	 ](../tasks610/plotweather.xml.rst	 )
# - [polcal 		 ](../tasks610/polcal.xml.rst		 )
# - [polfromgain 	 ](../tasks610/polfromgain.xml.rst	 )
# - [predictcomp 	 ](../tasks610/predictcomp.xml.rst	 )
# - [rerefant 	 ](../tasks610/rerefant.xml.rst	 )
# - [rmfit 		 ](../tasks610/rmfit.xml.rst		 )
# - [rmtables 	 ](../tasks610/rmtables.xml.rst	 )
# - [sdbaseline 	 ](../tasks610/sdbaseline.xml.rst	 )
# - [sdcal 		 ](../tasks610/sdcal.xml.rst		 )
# - [sdfit 		 ](../tasks610/sdfit.xml.rst		 )
# - [sdfixscan 	 ](../tasks610/sdfixscan.xml.rst	 )
# - [sdgaincal 	 ](../tasks610/sdgaincal.xml.rst	 )
# - [sdimaging 	 ](../tasks610/sdimaging.xml.rst	 )
# - [sdintimaging 	 ](../tasks610/sdintimaging.xml.rst	 )
# - [sdpolaverage 	 ](../tasks610/sdpolaverage.xml.rst	 )
# - [sdsidebandsplit  ](../tasks610/sdsidebandsplit.xml.rst	 )
# - [sdsmooth 	 ](../tasks610/sdsmooth.xml.rst	 )
# - [sdtimeaverage 	 ](../tasks610/sdtimeaverage.xml.rst	 )
# - [setjy 		 ](../tasks610/setjy.xml.rst		 )
# - [simalma 	 ](../tasks610/simalma.xml.rst		 )
# - [simanalyze 	 ](../tasks610/simanalyze.xml.rst	 )
# - [simobserve 	 ](../tasks610/simobserve.xml.rst	 )
# - [slsearch 	 ](../tasks610/slsearch.xml.rst	 )
# - [smoothcal 	 ](../tasks610/smoothcal.xml.rst	 )
# - [specfit 	 ](../tasks610/specfit.xml.rst		 )
# - [specflux 	 ](../tasks610/specflux.xml.rst	 )
# - [specsmooth 	 ](../tasks610/specsmooth.xml.rst	 )
# - [splattotable 	 ](../tasks610/splattotable.xml.rst	 )
# - [split 		 ](../tasks610/split.xml.rst		 )
# - [spxfit 		 ](../tasks610/spxfit.xml.rst		 )
# - [statwt 		 ](../tasks610/statwt.xml.rst		 )
# - [tclean 		 ](../tasks610/tclean.xml.rst		 )
# - [tclean2 	 ](../tasks610/tclean2.xml.rst		 )
# - [testconcat 	 ](../tasks610/testconcat.xml.rst	 )
# - [tsdimaging 	 ](../tasks610/tsdimaging.xml.rst	 )
# - [uvcontsub 	 ](../tasks610/uvcontsub.xml.rst	 )
# - [uvcontsub3 	 ](../tasks610/uvcontsub3.xml.rst	 )
# - [uvmodelfit 	 ](../tasks610/uvmodelfit.xml.rst	 )
# - [uvsub 		 ](../tasks610/uvsub.xml.rst		 )
# - [viewer 		 ](../tasks610/viewer.xml.rst		 )
# - [virtualconcat 	 ](../tasks610/virtualconcat.xml.rst	 )
# - [vishead 	 ](../tasks610/vishead.xml.rst		 )
# - [visstat 	 ](../tasks610/visstat.xml.rst		 )
# - [widebandpbcor 	 ](../tasks610/widebandpbcor.xml.rst	 )
# - [wvrgcal          ](../tasks610/wvrgcal.xml.rst          )
#
#
# ## Download
#
# Original XML files 5.7.0/6.1.0: [download here](https://drive.google.com/file/d/12pQ73raYhedz9EIfHYqxx_aJpYKTnLOo/view?usp=drive_link)
