# %% [markdown]
# <a href="https://colab.research.google.com/github/casangi/casadocs/blob/CAS-14318/docs/notebooks/XML500.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # XML information CASA 5.0.0
#
# - [accum		 ](../tasks500/accum.xml.rst		    )
# - [applycal	 ](../tasks500/applycal.xml.rst	    )
# - [asdmsummary	 ](../tasks500/asdmsummary.xml.rst	    )
# - [autoclean	 ](../tasks500/autoclean.xml.rst	    )
# - [bandpass	 ](../tasks500/bandpass.xml.rst	    )
# - [blcal		 ](../tasks500/blcal.xml.rst		    )
# - [boxit		 ](../tasks500/boxit.xml.rst		    )
# - [browsetable	 ](../tasks500/browsetable.xml.rst	    )
# - [calstat		 ](../tasks500/calstat.xml.rst		    )
# - [caltabconvert	 ](../tasks500/caltabconvert.xml.rst	    )
# - [clean		 ](../tasks500/clean.xml.rst		    )
# - [clearcal	 ](../tasks500/clearcal.xml.rst	    )
# - [clearplot	 ](../tasks500/clearplot.xml.rst	    )
# - [clearstat	 ](../tasks500/clearstat.xml.rst	    )
# - [concat		 ](../tasks500/concat.xml.rst		    )
# - [conjugatevis	 ](../tasks500/conjugatevis.xml.rst	    )
# - [csvclean	 ](../tasks500/csvclean.xml.rst	    )
# - [cvel		 ](../tasks500/cvel.xml.rst		    )
# - [cvel2		 ](../tasks500/cvel2.xml.rst		    )
# - [deconvolve	 ](../tasks500/deconvolve.xml.rst	    )
# - [delmod		 ](../tasks500/delmod.xml.rst		    )
# - [exportasdm	 ](../tasks500/exportasdm.xml.rst	    )
# - [exportfits	 ](../tasks500/exportfits.xml.rst	    )
# - [exportuvfits	 ](../tasks500/exportuvfits.xml.rst	    )
# - [feather		 ](../tasks500/feather.xml.rst		    )
# - [find		 ](../tasks500/find.xml.rst		    )
# - [fixplanets	 ](../tasks500/fixplanets.xml.rst	    )
# - [fixvis		 ](../tasks500/fixvis.xml.rst		    )
# - [flagcmd		 ](../tasks500/flagcmd.xml.rst		    )
# - [flagdata	 ](../tasks500/flagdata.xml.rst	    )
# - [flagmanager	 ](../tasks500/flagmanager.xml.rst	    )
# - [fluxscale	 ](../tasks500/fluxscale.xml.rst	    )
# - [ft		 ](../tasks500/ft.xml.rst		    )
# - [gaincal		 ](../tasks500/gaincal.xml.rst		    )
# - [gencal		 ](../tasks500/gencal.xml.rst		    )
# - [hanningsmooth	 ](../tasks500/hanningsmooth.xml.rst	    )
# - [imcollapse	 ](../tasks500/imcollapse.xml.rst	    )
# - [imcontsub	 ](../tasks500/imcontsub.xml.rst	    )
# - [imdev		 ](../tasks500/imdev.xml.rst		    )
# - [imfit		 ](../tasks500/imfit.xml.rst		    )
# - [imhead		 ](../tasks500/imhead.xml.rst		    )
# - [imhistory	 ](../tasks500/imhistory.xml.rst	    )
# - [immath		 ](../tasks500/immath.xml.rst		    )
# - [immoments	 ](../tasks500/immoments.xml.rst	    )
# - [impbcor		 ](../tasks500/impbcor.xml.rst		    )
# - [importasap	 ](../tasks500/importasap.xml.rst	    )
# - [importasdm	 ](../tasks500/importasdm.xml.rst	    )
# - [importatca	 ](../tasks500/importatca.xml.rst	    )
# - [importevla	 ](../tasks500/importevla.xml.rst	    )
# - [importfits	 ](../tasks500/importfits.xml.rst	    )
# - [importfitsidi	 ](../tasks500/importfitsidi.xml.rst	    )
# - [importgmrt	 ](../tasks500/importgmrt.xml.rst	    )
# - [importmiriad	 ](../tasks500/importmiriad.xml.rst	    )
# - [importnro	 ](../tasks500/importnro.xml.rst	    )
# - [importuvfits	 ](../tasks500/importuvfits.xml.rst	    )
# - [importvla	 ](../tasks500/importvla.xml.rst	    )
# - [impv		 ](../tasks500/impv.xml.rst		    )
# - [imrebin		 ](../tasks500/imrebin.xml.rst		    )
# - [imreframe	 ](../tasks500/imreframe.xml.rst	    )
# - [imregrid	 ](../tasks500/imregrid.xml.rst	    )
# - [imsmooth	 ](../tasks500/imsmooth.xml.rst	    )
# - [imstat		 ](../tasks500/imstat.xml.rst		    )
# - [imsubimage	 ](../tasks500/imsubimage.xml.rst	    )
# - [imtrans		 ](../tasks500/imtrans.xml.rst		    )
# - [imval		 ](../tasks500/imval.xml.rst		    )
# - [imview		 ](../tasks500/imview.xml.rst		    )
# - [initweights	 ](../tasks500/initweights.xml.rst	    )
# - [listcal		 ](../tasks500/listcal.xml.rst		    )
# - [listfits	 ](../tasks500/listfits.xml.rst	    )
# - [listhistory	 ](../tasks500/listhistory.xml.rst	    )
# - [listobs		 ](../tasks500/listobs.xml.rst		    )
# - [listpartition	 ](../tasks500/listpartition.xml.rst	    )
# - [listsdm		 ](../tasks500/listsdm.xml.rst		    )
# - [listvis		 ](../tasks500/listvis.xml.rst		    )
# - [makemask	 ](../tasks500/makemask.xml.rst	    )
# - [mosaic		 ](../tasks500/mosaic.xml.rst		    )
# - [mstransform	 ](../tasks500/mstransform.xml.rst	    )
# - [msuvbin		 ](../tasks500/msuvbin.xml.rst		    )
# - [msview		 ](../tasks500/msview.xml.rst		    )
# - [oldhanningsmooth ](../tasks500/oldhanningsmooth.xml.rst    )
# - [oldsplit	 ](../tasks500/oldsplit.xml.rst	    )
# - [partition	 ](../tasks500/partition.xml.rst	    )
# - [plotants	 ](../tasks500/plotants.xml.rst	    )
# - [plotbandpass	 ](../tasks500/plotbandpass.xml.rst	    )
# - [plotcal		 ](../tasks500/plotcal.xml.rst		    )
# - [plotms		 ](../tasks500/plotms.xml.rst		    )
# - [plotprofilemap	 ](../tasks500/plotprofilemap.xml.rst	    )
# - [plotuv		 ](../tasks500/plotuv.xml.rst		    )
# - [plotweather	 ](../tasks500/plotweather.xml.rst	    )
# - [polcal		 ](../tasks500/polcal.xml.rst		    )
# - [predictcomp	 ](../tasks500/predictcomp.xml.rst	    )
# - [rmfit		 ](../tasks500/rmfit.xml.rst		    )
# - [rmtables	 ](../tasks500/rmtables.xml.rst	    )
# - [sdaverageold	 ](../tasks500/sdaverageold.xml.rst	    )
# - [sdbaseline	 ](../tasks500/sdbaseline.xml.rst	    )
# - [sdbaseline2old	 ](../tasks500/sdbaseline2old.xml.rst	    )
# - [sdbaselineold	 ](../tasks500/sdbaselineold.xml.rst	    )
# - [sdcal		 ](../tasks500/sdcal.xml.rst		    )
# - [sdcal2old	 ](../tasks500/sdcal2old.xml.rst	    )
# - [sdcalold	 ](../tasks500/sdcalold.xml.rst	    )
# - [sdcoaddold	 ](../tasks500/sdcoaddold.xml.rst	    )
# - [sdfit		 ](../tasks500/sdfit.xml.rst		    )
# - [sdfitold	 ](../tasks500/sdfitold.xml.rst	    )
# - [sdflagmanagerold ](../tasks500/sdflagmanagerold.xml.rst    )
# - [sdflagold	 ](../tasks500/sdflagold.xml.rst	    )
# - [sdgaincal	 ](../tasks500/sdgaincal.xml.rst	    )
# - [sdgridold	 ](../tasks500/sdgridold.xml.rst	    )
# - [sdimaging	 ](../tasks500/sdimaging.xml.rst	    )
# - [sdimprocess	 ](../tasks500/sdimprocess.xml.rst	    )
# - [sdlistold	 ](../tasks500/sdlistold.xml.rst	    )
# - [sdmathold	 ](../tasks500/sdmathold.xml.rst	    )
# - [sdplotold	 ](../tasks500/sdplotold.xml.rst	    )
# - [sdreduceold	 ](../tasks500/sdreduceold.xml.rst	    )
# - [sdsaveold	 ](../tasks500/sdsaveold.xml.rst	    )
# - [sdscaleold	 ](../tasks500/sdscaleold.xml.rst	    )
# - [sdsmooth	 ](../tasks500/sdsmooth.xml.rst	    )
# - [sdstatold	 ](../tasks500/sdstatold.xml.rst	    )
# - [setjy		 ](../tasks500/setjy.xml.rst		    )
# - [simalma		 ](../tasks500/simalma.xml.rst		    )
# - [simanalyze	 ](../tasks500/simanalyze.xml.rst	    )
# - [simobserve	 ](../tasks500/simobserve.xml.rst	    )
# - [slsearch	 ](../tasks500/slsearch.xml.rst	    )
# - [smoothcal	 ](../tasks500/smoothcal.xml.rst	    )
# - [specfit		 ](../tasks500/specfit.xml.rst		    )
# - [specflux	 ](../tasks500/specflux.xml.rst	    )
# - [specsmooth	 ](../tasks500/specsmooth.xml.rst	    )
# - [splattotable	 ](../tasks500/splattotable.xml.rst	    )
# - [split		 ](../tasks500/split.xml.rst		    )
# - [spxfit		 ](../tasks500/spxfit.xml.rst		    )
# - [ssoflux		 ](../tasks500/ssoflux.xml.rst		    )
# - [statwt		 ](../tasks500/statwt.xml.rst		    )
# - [statwt2		 ](../tasks500/statwt2.xml.rst		    )
# - [tclean		 ](../tasks500/tclean.xml.rst		    )
# - [tclean2		 ](../tasks500/tclean2.xml.rst		    )
# - [testconcat	 ](../tasks500/testconcat.xml.rst	    )
# - [uvcontsub	 ](../tasks500/uvcontsub.xml.rst	    )
# - [uvcontsub3	 ](../tasks500/uvcontsub3.xml.rst	    )
# - [uvmodelfit	 ](../tasks500/uvmodelfit.xml.rst	    )
# - [uvsub		 ](../tasks500/uvsub.xml.rst		    )
# - [viewer		 ](../tasks500/viewer.xml.rst		    )
# - [virtualconcat	 ](../tasks500/virtualconcat.xml.rst	    )
# - [vishead		 ](../tasks500/vishead.xml.rst		    )
# - [visstat		 ](../tasks500/visstat.xml.rst		    )
# - [visstat2	 ](../tasks500/visstat2.xml.rst	    )
# - [widebandpbcor	 ](../tasks500/widebandpbcor.xml.rst	    )
# - [widefield	 ](../tasks500/widefield.xml.rst	    )
# - [wvrgcal          ](../tasks500/wvrgcal.xml.rst             )
#
#
# ## Download
#
# Original XML files 5.0.0: [download here](https://drive.google.com/file/d/1RONjam0xMRzMxwLSysAXjpR19mDrUHvh/view?usp=drive_link)
