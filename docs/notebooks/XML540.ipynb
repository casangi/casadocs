# %% [markdown]
# <a href="https://colab.research.google.com/github/casangi/casadocs/blob/CAS-14318/docs/notebooks/XML540.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # XML information CASA 5.4.0
#
# - [accor 		 ](../tasks540/accor.xml.rst		 )
# - [accum 		 ](../tasks540/accum.xml.rst		 )
# - [apparentsens 	 ](../tasks540/apparentsens.xml.rst	 )
# - [applycal 	 ](../tasks540/applycal.xml.rst	 )
# - [asdmsummary 	 ](../tasks540/asdmsummary.xml.rst	 )
# - [bandpass 	 ](../tasks540/bandpass.xml.rst	 )
# - [blcal 		 ](../tasks540/blcal.xml.rst		 )
# - [browsetable 	 ](../tasks540/browsetable.xml.rst	 )
# - [calstat 	 ](../tasks540/calstat.xml.rst		 )
# - [caltabconvert 	 ](../tasks540/caltabconvert.xml.rst	 )
# - [clean 		 ](../tasks540/clean.xml.rst		 )
# - [clearcal 	 ](../tasks540/clearcal.xml.rst	 )
# - [clearstat 	 ](../tasks540/clearstat.xml.rst	 )
# - [concat 		 ](../tasks540/concat.xml.rst		 )
# - [conjugatevis 	 ](../tasks540/conjugatevis.xml.rst	 )
# - [cvel 		 ](../tasks540/cvel.xml.rst		 )
# - [cvel2 		 ](../tasks540/cvel2.xml.rst		 )
# - [deconvolve 	 ](../tasks540/deconvolve.xml.rst	 )
# - [delmod 		 ](../tasks540/delmod.xml.rst		 )
# - [exportasdm 	 ](../tasks540/exportasdm.xml.rst	 )
# - [exportfits 	 ](../tasks540/exportfits.xml.rst	 )
# - [exportuvfits 	 ](../tasks540/exportuvfits.xml.rst	 )
# - [feather 	 ](../tasks540/feather.xml.rst		 )
# - [fixplanets 	 ](../tasks540/fixplanets.xml.rst	 )
# - [fixvis 		 ](../tasks540/fixvis.xml.rst		 )
# - [flagcmd 	 ](../tasks540/flagcmd.xml.rst		 )
# - [flagdata 	 ](../tasks540/flagdata.xml.rst	 )
# - [flagmanager 	 ](../tasks540/flagmanager.xml.rst	 )
# - [fluxscale 	 ](../tasks540/fluxscale.xml.rst	 )
# - [fringefit 	 ](../tasks540/fringefit.xml.rst	 )
# - [ft 		 ](../tasks540/ft.xml.rst		 )
# - [gaincal 	 ](../tasks540/gaincal.xml.rst		 )
# - [gencal 		 ](../tasks540/gencal.xml.rst		 )
# - [hanningsmooth 	 ](../tasks540/hanningsmooth.xml.rst	 )
# - [imcollapse 	 ](../tasks540/imcollapse.xml.rst	 )
# - [imcontsub 	 ](../tasks540/imcontsub.xml.rst	 )
# - [imdev 		 ](../tasks540/imdev.xml.rst		 )
# - [imfit 		 ](../tasks540/imfit.xml.rst		 )
# - [imhead 		 ](../tasks540/imhead.xml.rst		 )
# - [imhistory 	 ](../tasks540/imhistory.xml.rst	 )
# - [immath 		 ](../tasks540/immath.xml.rst		 )
# - [immoments 	 ](../tasks540/immoments.xml.rst	 )
# - [impbcor 	 ](../tasks540/impbcor.xml.rst		 )
# - [importasap 	 ](../tasks540/importasap.xml.rst	 )
# - [importasdm 	 ](../tasks540/importasdm.xml.rst	 )
# - [importatca 	 ](../tasks540/importatca.xml.rst	 )
# - [importfits 	 ](../tasks540/importfits.xml.rst	 )
# - [importfitsidi 	 ](../tasks540/importfitsidi.xml.rst	 )
# - [importgmrt 	 ](../tasks540/importgmrt.xml.rst	 )
# - [importmiriad 	 ](../tasks540/importmiriad.xml.rst	 )
# - [importnro 	 ](../tasks540/importnro.xml.rst	 )
# - [importuvfits 	 ](../tasks540/importuvfits.xml.rst	 )
# - [importvla 	 ](../tasks540/importvla.xml.rst	 )
# - [impv 		 ](../tasks540/impv.xml.rst		 )
# - [imrebin 	 ](../tasks540/imrebin.xml.rst		 )
# - [imreframe 	 ](../tasks540/imreframe.xml.rst	 )
# - [imregrid 	 ](../tasks540/imregrid.xml.rst	 )
# - [imsmooth 	 ](../tasks540/imsmooth.xml.rst	 )
# - [imstat 		 ](../tasks540/imstat.xml.rst		 )
# - [imsubimage 	 ](../tasks540/imsubimage.xml.rst	 )
# - [imtrans 	 ](../tasks540/imtrans.xml.rst		 )
# - [imval 		 ](../tasks540/imval.xml.rst		 )
# - [imview 		 ](../tasks540/imview.xml.rst		 )
# - [initweights 	 ](../tasks540/initweights.xml.rst	 )
# - [listcal 	 ](../tasks540/listcal.xml.rst		 )
# - [listfits 	 ](../tasks540/listfits.xml.rst	 )
# - [listhistory 	 ](../tasks540/listhistory.xml.rst	 )
# - [listobs 	 ](../tasks540/listobs.xml.rst		 )
# - [listpartition 	 ](../tasks540/listpartition.xml.rst	 )
# - [listsdm 	 ](../tasks540/listsdm.xml.rst		 )
# - [listvis 	 ](../tasks540/listvis.xml.rst		 )
# - [makemask 	 ](../tasks540/makemask.xml.rst	 )
# - [mstransform 	 ](../tasks540/mstransform.xml.rst	 )
# - [msuvbin 	 ](../tasks540/msuvbin.xml.rst		 )
# - [msview 		 ](../tasks540/msview.xml.rst		 )
# - [nrobeamaverage 	 ](../tasks540/nrobeamaverage.xml.rst	 )
# - [oldsplit 	 ](../tasks540/oldsplit.xml.rst	 )
# - [oldstatwt 	 ](../tasks540/oldstatwt.xml.rst	 )
# - [partition 	 ](../tasks540/partition.xml.rst	 )
# - [plotants 	 ](../tasks540/plotants.xml.rst	 )
# - [plotbandpass 	 ](../tasks540/plotbandpass.xml.rst	 )
# - [plotcal 	 ](../tasks540/plotcal.xml.rst		 )
# - [plotms 		 ](../tasks540/plotms.xml.rst		 )
# - [plotprofilemap 	 ](../tasks540/plotprofilemap.xml.rst	 )
# - [plotweather 	 ](../tasks540/plotweather.xml.rst	 )
# - [polcal 		 ](../tasks540/polcal.xml.rst		 )
# - [polfromgain 	 ](../tasks540/polfromgain.xml.rst	 )
# - [predictcomp 	 ](../tasks540/predictcomp.xml.rst	 )
# - [rerefant 	 ](../tasks540/rerefant.xml.rst	 )
# - [rmfit 		 ](../tasks540/rmfit.xml.rst		 )
# - [rmtables 	 ](../tasks540/rmtables.xml.rst	 )
# - [sdbaseline 	 ](../tasks540/sdbaseline.xml.rst	 )
# - [sdcal 		 ](../tasks540/sdcal.xml.rst		 )
# - [sdfit 		 ](../tasks540/sdfit.xml.rst		 )
# - [sdfixscan 	 ](../tasks540/sdfixscan.xml.rst	 )
# - [sdgaincal 	 ](../tasks540/sdgaincal.xml.rst	 )
# - [sdimaging 	 ](../tasks540/sdimaging.xml.rst	 )
# - [sdintimaging 	 ](../tasks540/sdintimaging.xml.rst	 )
# - [sdpolaverage 	 ](../tasks540/sdpolaverage.xml.rst	 )
# - [sdsidebandsplit  ](../tasks540/sdsidebandsplit.xml.rst	 )
# - [sdsmooth 	 ](../tasks540/sdsmooth.xml.rst	 )
# - [sdtimeaverage 	 ](../tasks540/sdtimeaverage.xml.rst	 )
# - [setjy 		 ](../tasks540/setjy.xml.rst		 )
# - [simalma 	 ](../tasks540/simalma.xml.rst		 )
# - [simanalyze 	 ](../tasks540/simanalyze.xml.rst	 )
# - [simobserve 	 ](../tasks540/simobserve.xml.rst	 )
# - [slsearch 	 ](../tasks540/slsearch.xml.rst	 )
# - [smoothcal 	 ](../tasks540/smoothcal.xml.rst	 )
# - [specfit 	 ](../tasks540/specfit.xml.rst		 )
# - [specflux 	 ](../tasks540/specflux.xml.rst	 )
# - [specsmooth 	 ](../tasks540/specsmooth.xml.rst	 )
# - [splattotable 	 ](../tasks540/splattotable.xml.rst	 )
# - [split 		 ](../tasks540/split.xml.rst		 )
# - [spxfit 		 ](../tasks540/spxfit.xml.rst		 )
# - [statwt 		 ](../tasks540/statwt.xml.rst		 )
# - [tclean 		 ](../tasks540/tclean.xml.rst		 )
# - [tclean2 	 ](../tasks540/tclean2.xml.rst		 )
# - [testconcat 	 ](../tasks540/testconcat.xml.rst	 )
# - [tsdimaging 	 ](../tasks540/tsdimaging.xml.rst	 )
# - [uvcontsub 	 ](../tasks540/uvcontsub.xml.rst	 )
# - [uvcontsub3 	 ](../tasks540/uvcontsub3.xml.rst	 )
# - [uvmodelfit 	 ](../tasks540/uvmodelfit.xml.rst	 )
# - [uvsub 		 ](../tasks540/uvsub.xml.rst		 )
# - [viewer 		 ](../tasks540/viewer.xml.rst		 )
# - [virtualconcat 	 ](../tasks540/virtualconcat.xml.rst	 )
# - [vishead 	 ](../tasks540/vishead.xml.rst		 )
# - [visstat 	 ](../tasks540/visstat.xml.rst		 )
# - [widebandpbcor 	 ](../tasks540/widebandpbcor.xml.rst	 )
# - [wvrgcal          ](../tasks540/wvrgcal.xml.rst          )
#
# ## Download
#
# Original XML files 5.4.0: [download here](https://drive.google.com/file/d/1hZLJUnquLoGh5-CCYgSi4MvbCHCnO1Or/view?usp=drive_link)
