# %% [markdown]
# <a href="https://colab.research.google.com/github/casangi/casadocs/blob/CAS-14318/docs/notebooks/XML562.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # XML information CASA 5.6.2
#
# - [accor		  ](../tasks562/accor.xml.rst		 )
# - [accum		  ](../tasks562/accum.xml.rst		 )
# - [apparentsens	  ](../tasks562/apparentsens.xml.rst	 )
# - [applycal	  ](../tasks562/applycal.xml.rst	 )
# - [asdmsummary	  ](../tasks562/asdmsummary.xml.rst	 )
# - [bandpass	  ](../tasks562/bandpass.xml.rst	 )
# - [blcal		  ](../tasks562/blcal.xml.rst		 )
# - [browsetable	  ](../tasks562/browsetable.xml.rst	 )
# - [calstat		  ](../tasks562/calstat.xml.rst		 )
# - [caltabconvert	  ](../tasks562/caltabconvert.xml.rst	 )
# - [clean		  ](../tasks562/clean.xml.rst		 )
# - [clearcal	  ](../tasks562/clearcal.xml.rst	 )
# - [clearstat	  ](../tasks562/clearstat.xml.rst	 )
# - [concat		  ](../tasks562/concat.xml.rst		 )
# - [conjugatevis	  ](../tasks562/conjugatevis.xml.rst	 )
# - [cvel		  ](../tasks562/cvel.xml.rst		 )
# - [cvel2		  ](../tasks562/cvel2.xml.rst		 )
# - [deconvolve	  ](../tasks562/deconvolve.xml.rst	 )
# - [delmod		  ](../tasks562/delmod.xml.rst		 )
# - [exportasdm	  ](../tasks562/exportasdm.xml.rst	 )
# - [exportfits	  ](../tasks562/exportfits.xml.rst	 )
# - [exportuvfits	  ](../tasks562/exportuvfits.xml.rst	 )
# - [feather		  ](../tasks562/feather.xml.rst		 )
# - [fixplanets	  ](../tasks562/fixplanets.xml.rst	 )
# - [fixvis		  ](../tasks562/fixvis.xml.rst		 )
# - [flagcmd		  ](../tasks562/flagcmd.xml.rst		 )
# - [flagdata	  ](../tasks562/flagdata.xml.rst	 )
# - [flagmanager	  ](../tasks562/flagmanager.xml.rst	 )
# - [fluxscale	  ](../tasks562/fluxscale.xml.rst	 )
# - [fringefit	  ](../tasks562/fringefit.xml.rst	 )
# - [ft		  ](../tasks562/ft.xml.rst		 )
# - [gaincal		  ](../tasks562/gaincal.xml.rst		 )
# - [gencal		  ](../tasks562/gencal.xml.rst		 )
# - [hanningsmooth	  ](../tasks562/hanningsmooth.xml.rst	 )
# - [imcollapse	  ](../tasks562/imcollapse.xml.rst	 )
# - [imcontsub	  ](../tasks562/imcontsub.xml.rst	 )
# - [imdev		  ](../tasks562/imdev.xml.rst		 )
# - [imfit		  ](../tasks562/imfit.xml.rst		 )
# - [imhead		  ](../tasks562/imhead.xml.rst		 )
# - [imhistory	  ](../tasks562/imhistory.xml.rst	 )
# - [immath		  ](../tasks562/immath.xml.rst		 )
# - [immoments	  ](../tasks562/immoments.xml.rst	 )
# - [impbcor		  ](../tasks562/impbcor.xml.rst		 )
# - [importasap	  ](../tasks562/importasap.xml.rst	 )
# - [importasdm	  ](../tasks562/importasdm.xml.rst	 )
# - [importatca	  ](../tasks562/importatca.xml.rst	 )
# - [importfits	  ](../tasks562/importfits.xml.rst	 )
# - [importfitsidi	  ](../tasks562/importfitsidi.xml.rst	 )
# - [importgmrt	  ](../tasks562/importgmrt.xml.rst	 )
# - [importmiriad	  ](../tasks562/importmiriad.xml.rst	 )
# - [importnro	  ](../tasks562/importnro.xml.rst	 )
# - [importuvfits	  ](../tasks562/importuvfits.xml.rst	 )
# - [importvla	  ](../tasks562/importvla.xml.rst	 )
# - [impv		  ](../tasks562/impv.xml.rst		 )
# - [imrebin		  ](../tasks562/imrebin.xml.rst		 )
# - [imreframe	  ](../tasks562/imreframe.xml.rst	 )
# - [imregrid	  ](../tasks562/imregrid.xml.rst	 )
# - [imsmooth	  ](../tasks562/imsmooth.xml.rst	 )
# - [imstat		  ](../tasks562/imstat.xml.rst		 )
# - [imsubimage	  ](../tasks562/imsubimage.xml.rst	 )
# - [imtrans		  ](../tasks562/imtrans.xml.rst		 )
# - [imval		  ](../tasks562/imval.xml.rst		 )
# - [imview		  ](../tasks562/imview.xml.rst		 )
# - [initweights	  ](../tasks562/initweights.xml.rst	 )
# - [listcal		  ](../tasks562/listcal.xml.rst		 )
# - [listfits	  ](../tasks562/listfits.xml.rst	 )
# - [listhistory	  ](../tasks562/listhistory.xml.rst	 )
# - [listobs		  ](../tasks562/listobs.xml.rst		 )
# - [listpartition	  ](../tasks562/listpartition.xml.rst	 )
# - [listsdm		  ](../tasks562/listsdm.xml.rst		 )
# - [listvis		  ](../tasks562/listvis.xml.rst		 )
# - [makemask	  ](../tasks562/makemask.xml.rst	 )
# - [mstransform	  ](../tasks562/mstransform.xml.rst	 )
# - [msuvbin		  ](../tasks562/msuvbin.xml.rst		 )
# - [msview		  ](../tasks562/msview.xml.rst		 )
# - [nrobeamaverage	  ](../tasks562/nrobeamaverage.xml.rst	 )
# - [oldsplit	  ](../tasks562/oldsplit.xml.rst	 )
# - [oldstatwt	  ](../tasks562/oldstatwt.xml.rst	 )
# - [partition	  ](../tasks562/partition.xml.rst	 )
# - [plotants	  ](../tasks562/plotants.xml.rst	 )
# - [plotbandpass	  ](../tasks562/plotbandpass.xml.rst	 )
# - [plotcal		  ](../tasks562/plotcal.xml.rst		 )
# - [plotms		  ](../tasks562/plotms.xml.rst		 )
# - [plotprofilemap	  ](../tasks562/plotprofilemap.xml.rst	 )
# - [plotweather	  ](../tasks562/plotweather.xml.rst	 )
# - [polcal		  ](../tasks562/polcal.xml.rst		 )
# - [polfromgain	  ](../tasks562/polfromgain.xml.rst	 )
# - [predictcomp	  ](../tasks562/predictcomp.xml.rst	 )
# - [rerefant	  ](../tasks562/rerefant.xml.rst	 )
# - [rmfit		  ](../tasks562/rmfit.xml.rst		 )
# - [rmtables	  ](../tasks562/rmtables.xml.rst	 )
# - [sdbaseline	  ](../tasks562/sdbaseline.xml.rst	 )
# - [sdcal		  ](../tasks562/sdcal.xml.rst		 )
# - [sdfit		  ](../tasks562/sdfit.xml.rst		 )
# - [sdfixscan	  ](../tasks562/sdfixscan.xml.rst	 )
# - [sdgaincal	  ](../tasks562/sdgaincal.xml.rst	 )
# - [sdimaging	  ](../tasks562/sdimaging.xml.rst	 )
# - [sdpolaverage	  ](../tasks562/sdpolaverage.xml.rst	 )
# - [sdsidebandsplit	  ](../tasks562/sdsidebandsplit.xml.rst	 )
# - [sdsmooth	  ](../tasks562/sdsmooth.xml.rst	 )
# - [setjy		  ](../tasks562/setjy.xml.rst		 )
# - [simalma		  ](../tasks562/simalma.xml.rst		 )
# - [simanalyze	  ](../tasks562/simanalyze.xml.rst	 )
# - [simobserve	  ](../tasks562/simobserve.xml.rst	 )
# - [slsearch	  ](../tasks562/slsearch.xml.rst	 )
# - [smoothcal	  ](../tasks562/smoothcal.xml.rst	 )
# - [specfit		  ](../tasks562/specfit.xml.rst		 )
# - [specflux	  ](../tasks562/specflux.xml.rst	 )
# - [specsmooth	  ](../tasks562/specsmooth.xml.rst	 )
# - [splattotable	  ](../tasks562/splattotable.xml.rst	 )
# - [split		  ](../tasks562/split.xml.rst		 )
# - [spxfit		  ](../tasks562/spxfit.xml.rst		 )
# - [statwt		  ](../tasks562/statwt.xml.rst		 )
# - [tclean		  ](../tasks562/tclean.xml.rst		 )
# - [tclean2		  ](../tasks562/tclean2.xml.rst		 )
# - [testconcat	  ](../tasks562/testconcat.xml.rst	 )
# - [tsdimaging	  ](../tasks562/tsdimaging.xml.rst	 )
# - [uvcontsub	  ](../tasks562/uvcontsub.xml.rst	 )
# - [uvcontsub3	  ](../tasks562/uvcontsub3.xml.rst	 )
# - [uvmodelfit	  ](../tasks562/uvmodelfit.xml.rst	 )
# - [uvsub		  ](../tasks562/uvsub.xml.rst		 )
# - [viewer		  ](../tasks562/viewer.xml.rst		 )
# - [virtualconcat	  ](../tasks562/virtualconcat.xml.rst	 )
# - [vishead		  ](../tasks562/vishead.xml.rst		 )
# - [visstat		  ](../tasks562/visstat.xml.rst		 )
# - [widebandpbcor	  ](../tasks562/widebandpbcor.xml.rst	 )
# - [wvrgcal           ](../tasks562/wvrgcal.xml.rst          )
#
#
# ## Download
#
# Original XML files 5.6.2: [download here](https://drive.google.com/file/d/1_OAx4231Y6e6pb7J2shUVZuGoxqF05Vh/view?usp=drive_link)
