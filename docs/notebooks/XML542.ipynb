# %% [markdown]
# <a href="https://colab.research.google.com/github/casangi/casadocs/blob/CAS-14318/docs/notebooks/XML542.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # XML information CASA 5.4.2
#
# - [accor		   ](../tasks542/accor.xml.rst		  )
# - [accum		   ](../tasks542/accum.xml.rst		  )
# - [applycal	   ](../tasks542/applycal.xml.rst	  )
# - [asdmsummary	   ](../tasks542/asdmsummary.xml.rst	  )
# - [bandpass	   ](../tasks542/bandpass.xml.rst	  )
# - [blcal		   ](../tasks542/blcal.xml.rst		  )
# - [browsetable	   ](../tasks542/browsetable.xml.rst	  )
# - [calstat		   ](../tasks542/calstat.xml.rst		  )
# - [caltabconvert	   ](../tasks542/caltabconvert.xml.rst	  )
# - [clean		   ](../tasks542/clean.xml.rst		  )
# - [clearcal	   ](../tasks542/clearcal.xml.rst	  )
# - [clearstat	   ](../tasks542/clearstat.xml.rst	  )
# - [concat		   ](../tasks542/concat.xml.rst		  )
# - [conjugatevis	   ](../tasks542/conjugatevis.xml.rst	  )
# - [cvel		   ](../tasks542/cvel.xml.rst		  )
# - [cvel2		   ](../tasks542/cvel2.xml.rst		  )
# - [deconvolve	   ](../tasks542/deconvolve.xml.rst	  )
# - [delmod		   ](../tasks542/delmod.xml.rst		  )
# - [exportasdm	   ](../tasks542/exportasdm.xml.rst	  )
# - [exportfits	   ](../tasks542/exportfits.xml.rst	  )
# - [exportuvfits	   ](../tasks542/exportuvfits.xml.rst	  )
# - [feather		   ](../tasks542/feather.xml.rst		  )
# - [fixplanets	   ](../tasks542/fixplanets.xml.rst	  )
# - [fixvis		   ](../tasks542/fixvis.xml.rst		  )
# - [flagcmd		   ](../tasks542/flagcmd.xml.rst		  )
# - [flagdata	   ](../tasks542/flagdata.xml.rst	  )
# - [flagmanager	   ](../tasks542/flagmanager.xml.rst	  )
# - [fluxscale	   ](../tasks542/fluxscale.xml.rst	  )
# - [fringefit	   ](../tasks542/fringefit.xml.rst	  )
# - [ft		   ](../tasks542/ft.xml.rst		  )
# - [gaincal		   ](../tasks542/gaincal.xml.rst		  )
# - [gencal		   ](../tasks542/gencal.xml.rst		  )
# - [hanningsmooth	   ](../tasks542/hanningsmooth.xml.rst	  )
# - [imcollapse	   ](../tasks542/imcollapse.xml.rst	  )
# - [imcontsub	   ](../tasks542/imcontsub.xml.rst	  )
# - [imdev		   ](../tasks542/imdev.xml.rst		  )
# - [imfit		   ](../tasks542/imfit.xml.rst		  )
# - [imhead		   ](../tasks542/imhead.xml.rst		  )
# - [imhistory	   ](../tasks542/imhistory.xml.rst	  )
# - [immath		   ](../tasks542/immath.xml.rst		  )
# - [immoments	   ](../tasks542/immoments.xml.rst	  )
# - [impbcor		   ](../tasks542/impbcor.xml.rst		  )
# - [importasap	   ](../tasks542/importasap.xml.rst	  )
# - [importasdm	   ](../tasks542/importasdm.xml.rst	  )
# - [importatca	   ](../tasks542/importatca.xml.rst	  )
# - [importfits	   ](../tasks542/importfits.xml.rst	  )
# - [importfitsidi	   ](../tasks542/importfitsidi.xml.rst	  )
# - [importgmrt	   ](../tasks542/importgmrt.xml.rst	  )
# - [importmiriad	   ](../tasks542/importmiriad.xml.rst	  )
# - [importnro	   ](../tasks542/importnro.xml.rst	  )
# - [importuvfits	   ](../tasks542/importuvfits.xml.rst	  )
# - [importvla	   ](../tasks542/importvla.xml.rst	  )
# - [impv		   ](../tasks542/impv.xml.rst		  )
# - [imrebin		   ](../tasks542/imrebin.xml.rst		  )
# - [imreframe	   ](../tasks542/imreframe.xml.rst	  )
# - [imregrid	   ](../tasks542/imregrid.xml.rst	  )
# - [imsmooth	   ](../tasks542/imsmooth.xml.rst	  )
# - [imstat		   ](../tasks542/imstat.xml.rst		  )
# - [imsubimage	   ](../tasks542/imsubimage.xml.rst	  )
# - [imtrans		   ](../tasks542/imtrans.xml.rst		  )
# - [imval		   ](../tasks542/imval.xml.rst		  )
# - [imview		   ](../tasks542/imview.xml.rst		  )
# - [initweights	   ](../tasks542/initweights.xml.rst	  )
# - [listcal		   ](../tasks542/listcal.xml.rst		  )
# - [listfits	   ](../tasks542/listfits.xml.rst	  )
# - [listhistory	   ](../tasks542/listhistory.xml.rst	  )
# - [listobs		   ](../tasks542/listobs.xml.rst		  )
# - [listpartition	   ](../tasks542/listpartition.xml.rst	  )
# - [listsdm		   ](../tasks542/listsdm.xml.rst		  )
# - [listvis		   ](../tasks542/listvis.xml.rst		  )
# - [makemask	   ](../tasks542/makemask.xml.rst	  )
# - [mstransform	   ](../tasks542/mstransform.xml.rst	  )
# - [msuvbin		   ](../tasks542/msuvbin.xml.rst		  )
# - [msview		   ](../tasks542/msview.xml.rst		  )
# - [oldsplit	   ](../tasks542/oldsplit.xml.rst	  )
# - [oldstatwt	   ](../tasks542/oldstatwt.xml.rst	  )
# - [partition	   ](../tasks542/partition.xml.rst	  )
# - [plotants	   ](../tasks542/plotants.xml.rst	  )
# - [plotbandpass	   ](../tasks542/plotbandpass.xml.rst	  )
# - [plotcal		   ](../tasks542/plotcal.xml.rst		  )
# - [plotms		   ](../tasks542/plotms.xml.rst		  )
# - [plotprofilemap	   ](../tasks542/plotprofilemap.xml.rst	  )
# - [plotweather	   ](../tasks542/plotweather.xml.rst	  )
# - [polcal		   ](../tasks542/polcal.xml.rst		  )
# - [predictcomp	   ](../tasks542/predictcomp.xml.rst	  )
# - [rerefant	   ](../tasks542/rerefant.xml.rst	  )
# - [rmfit		   ](../tasks542/rmfit.xml.rst		  )
# - [rmtables	   ](../tasks542/rmtables.xml.rst	  )
# - [sdbaseline	   ](../tasks542/sdbaseline.xml.rst	  )
# - [sdcal		   ](../tasks542/sdcal.xml.rst		  )
# - [sdfit		   ](../tasks542/sdfit.xml.rst		  )
# - [sdfixscan	   ](../tasks542/sdfixscan.xml.rst	  )
# - [sdgaincal	   ](../tasks542/sdgaincal.xml.rst	  )
# - [sdimaging	   ](../tasks542/sdimaging.xml.rst	  )
# - [sdsidebandsplit	   ](../tasks542/sdsidebandsplit.xml.rst	  )
# - [sdsmooth	   ](../tasks542/sdsmooth.xml.rst	  )
# - [setjy		   ](../tasks542/setjy.xml.rst		  )
# - [simalma		   ](../tasks542/simalma.xml.rst		  )
# - [simanalyze	   ](../tasks542/simanalyze.xml.rst	  )
# - [simobserve	   ](../tasks542/simobserve.xml.rst	  )
# - [slsearch	   ](../tasks542/slsearch.xml.rst	  )
# - [smoothcal	   ](../tasks542/smoothcal.xml.rst	  )
# - [specfit		   ](../tasks542/specfit.xml.rst		  )
# - [specflux	   ](../tasks542/specflux.xml.rst	  )
# - [specsmooth	   ](../tasks542/specsmooth.xml.rst	  )
# - [splattotable	   ](../tasks542/splattotable.xml.rst	  )
# - [split		   ](../tasks542/split.xml.rst		  )
# - [spxfit		   ](../tasks542/spxfit.xml.rst		  )
# - [statwt		   ](../tasks542/statwt.xml.rst		  )
# - [tclean		   ](../tasks542/tclean.xml.rst		  )
# - [tclean2		   ](../tasks542/tclean2.xml.rst		  )
# - [testconcat	   ](../tasks542/testconcat.xml.rst	  )
# - [tsdimaging	   ](../tasks542/tsdimaging.xml.rst	  )
# - [uvcontsub	   ](../tasks542/uvcontsub.xml.rst	  )
# - [uvcontsub3	   ](../tasks542/uvcontsub3.xml.rst	  )
# - [uvmodelfit	   ](../tasks542/uvmodelfit.xml.rst	  )
# - [uvsub		   ](../tasks542/uvsub.xml.rst		  )
# - [viewer		   ](../tasks542/viewer.xml.rst		  )
# - [virtualconcat	   ](../tasks542/virtualconcat.xml.rst	  )
# - [vishead		   ](../tasks542/vishead.xml.rst		  )
# - [visstat		   ](../tasks542/visstat.xml.rst		  )
# - [widebandpbcor	   ](../tasks542/widebandpbcor.xml.rst	  )
# - [wvrgcal            ](../tasks542/wvrgcal.xml.rst           )
#
#
# ## Download
#
# Original XML files 5.4.2: [download here](https://drive.google.com/file/d/1ttt4Dv249Z3K69BvPiq1SNEWJFtQdgik/view?usp=drive_link)
