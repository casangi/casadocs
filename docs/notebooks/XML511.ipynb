# %% [markdown]
# <a href="https://colab.research.google.com/github/casangi/casadocs/blob/CAS-14318/docs/notebooks/XML511.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # XML information CASA 5.1.1
#
# - [accum		   ](../tasks511/accum.xml.rst		     )
# - [applycal	   ](../tasks511/applycal.xml.rst	     )
# - [asdmsummary	   ](../tasks511/asdmsummary.xml.rst	     )
# - [autoclean	   ](../tasks511/autoclean.xml.rst	     )
# - [bandpass	   ](../tasks511/bandpass.xml.rst	     )
# - [blcal		   ](../tasks511/blcal.xml.rst		     )
# - [boxit		   ](../tasks511/boxit.xml.rst		     )
# - [browsetable	   ](../tasks511/browsetable.xml.rst	     )
# - [calstat		   ](../tasks511/calstat.xml.rst		     )
# - [caltabconvert	   ](../tasks511/caltabconvert.xml.rst	     )
# - [clean		   ](../tasks511/clean.xml.rst		     )
# - [clearcal	   ](../tasks511/clearcal.xml.rst	     )
# - [clearplot	   ](../tasks511/clearplot.xml.rst	     )
# - [clearstat	   ](../tasks511/clearstat.xml.rst	     )
# - [concat		   ](../tasks511/concat.xml.rst		     )
# - [conjugatevis	   ](../tasks511/conjugatevis.xml.rst	     )
# - [csvclean	   ](../tasks511/csvclean.xml.rst	     )
# - [cvel		   ](../tasks511/cvel.xml.rst		     )
# - [cvel2		   ](../tasks511/cvel2.xml.rst		     )
# - [deconvolve	   ](../tasks511/deconvolve.xml.rst	     )
# - [delmod		   ](../tasks511/delmod.xml.rst		     )
# - [exportasdm	   ](../tasks511/exportasdm.xml.rst	     )
# - [exportfits	   ](../tasks511/exportfits.xml.rst	     )
# - [exportuvfits	   ](../tasks511/exportuvfits.xml.rst	     )
# - [feather		   ](../tasks511/feather.xml.rst		     )
# - [find		   ](../tasks511/find.xml.rst		     )
# - [fixplanets	   ](../tasks511/fixplanets.xml.rst	     )
# - [fixvis		   ](../tasks511/fixvis.xml.rst		     )
# - [flagcmd		   ](../tasks511/flagcmd.xml.rst		     )
# - [flagdata	   ](../tasks511/flagdata.xml.rst	     )
# - [flagmanager	   ](../tasks511/flagmanager.xml.rst	     )
# - [fluxscale	   ](../tasks511/fluxscale.xml.rst	     )
# - [ft		   ](../tasks511/ft.xml.rst		     )
# - [gaincal		   ](../tasks511/gaincal.xml.rst		     )
# - [gencal		   ](../tasks511/gencal.xml.rst		     )
# - [hanningsmooth	   ](../tasks511/hanningsmooth.xml.rst	     )
# - [imcollapse	   ](../tasks511/imcollapse.xml.rst	     )
# - [imcontsub	   ](../tasks511/imcontsub.xml.rst	     )
# - [imdev		   ](../tasks511/imdev.xml.rst		     )
# - [imfit		   ](../tasks511/imfit.xml.rst		     )
# - [imhead		   ](../tasks511/imhead.xml.rst		     )
# - [imhistory	   ](../tasks511/imhistory.xml.rst	     )
# - [immath		   ](../tasks511/immath.xml.rst		     )
# - [immoments	   ](../tasks511/immoments.xml.rst	     )
# - [impbcor		   ](../tasks511/impbcor.xml.rst		     )
# - [importasap	   ](../tasks511/importasap.xml.rst	     )
# - [importasdm	   ](../tasks511/importasdm.xml.rst	     )
# - [importatca	   ](../tasks511/importatca.xml.rst	     )
# - [importevla	   ](../tasks511/importevla.xml.rst	     )
# - [importfits	   ](../tasks511/importfits.xml.rst	     )
# - [importfitsidi	   ](../tasks511/importfitsidi.xml.rst	     )
# - [importgmrt	   ](../tasks511/importgmrt.xml.rst	     )
# - [importmiriad	   ](../tasks511/importmiriad.xml.rst	     )
# - [importnro	   ](../tasks511/importnro.xml.rst	     )
# - [importuvfits	   ](../tasks511/importuvfits.xml.rst	     )
# - [importvla	   ](../tasks511/importvla.xml.rst	     )
# - [impv		   ](../tasks511/impv.xml.rst		     )
# - [imrebin		   ](../tasks511/imrebin.xml.rst		     )
# - [imreframe	   ](../tasks511/imreframe.xml.rst	     )
# - [imregrid	   ](../tasks511/imregrid.xml.rst	     )
# - [imsmooth	   ](../tasks511/imsmooth.xml.rst	     )
# - [imstat		   ](../tasks511/imstat.xml.rst		     )
# - [imsubimage	   ](../tasks511/imsubimage.xml.rst	     )
# - [imtrans		   ](../tasks511/imtrans.xml.rst		     )
# - [imval		   ](../tasks511/imval.xml.rst		     )
# - [imview		   ](../tasks511/imview.xml.rst		     )
# - [initweights	   ](../tasks511/initweights.xml.rst	     )
# - [listcal		   ](../tasks511/listcal.xml.rst		     )
# - [listfits	   ](../tasks511/listfits.xml.rst	     )
# - [listhistory	   ](../tasks511/listhistory.xml.rst	     )
# - [listobs		   ](../tasks511/listobs.xml.rst		     )
# - [listpartition	   ](../tasks511/listpartition.xml.rst	     )
# - [listsdm		   ](../tasks511/listsdm.xml.rst		     )
# - [listvis		   ](../tasks511/listvis.xml.rst		     )
# - [makemask	   ](../tasks511/makemask.xml.rst	     )
# - [mosaic		   ](../tasks511/mosaic.xml.rst		     )
# - [mstransform	   ](../tasks511/mstransform.xml.rst	     )
# - [msuvbin		   ](../tasks511/msuvbin.xml.rst		     )
# - [msview		   ](../tasks511/msview.xml.rst		     )
# - [oldhanningsmooth   ](../tasks511/oldhanningsmooth.xml.rst     )
# - [oldsplit	   ](../tasks511/oldsplit.xml.rst	     )
# - [partition	   ](../tasks511/partition.xml.rst	     )
# - [plotants	   ](../tasks511/plotants.xml.rst	     )
# - [plotbandpass	   ](../tasks511/plotbandpass.xml.rst	     )
# - [plotcal		   ](../tasks511/plotcal.xml.rst		     )
# - [plotms		   ](../tasks511/plotms.xml.rst		     )
# - [plotprofilemap	   ](../tasks511/plotprofilemap.xml.rst	     )
# - [plotuv		   ](../tasks511/plotuv.xml.rst		     )
# - [plotweather	   ](../tasks511/plotweather.xml.rst	     )
# - [polcal		   ](../tasks511/polcal.xml.rst		     )
# - [predictcomp	   ](../tasks511/predictcomp.xml.rst	     )
# - [rerefant	   ](../tasks511/rerefant.xml.rst	     )
# - [rmfit		   ](../tasks511/rmfit.xml.rst		     )
# - [rmtables	   ](../tasks511/rmtables.xml.rst	     )
# - [sdbaseline	   ](../tasks511/sdbaseline.xml.rst	     )
# - [sdcal		   ](../tasks511/sdcal.xml.rst		     )
# - [sdfit		   ](../tasks511/sdfit.xml.rst		     )
# - [sdfixscan	   ](../tasks511/sdfixscan.xml.rst	     )
# - [sdgaincal	   ](../tasks511/sdgaincal.xml.rst	     )
# - [sdimaging	   ](../tasks511/sdimaging.xml.rst	     )
# - [sdsmooth	   ](../tasks511/sdsmooth.xml.rst	     )
# - [setjy		   ](../tasks511/setjy.xml.rst		     )
# - [simalma		   ](../tasks511/simalma.xml.rst		     )
# - [simanalyze	   ](../tasks511/simanalyze.xml.rst	     )
# - [simobserve	   ](../tasks511/simobserve.xml.rst	     )
# - [slsearch	   ](../tasks511/slsearch.xml.rst	     )
# - [smoothcal	   ](../tasks511/smoothcal.xml.rst	     )
# - [specfit		   ](../tasks511/specfit.xml.rst		     )
# - [specflux	   ](../tasks511/specflux.xml.rst	     )
# - [specsmooth	   ](../tasks511/specsmooth.xml.rst	     )
# - [splattotable	   ](../tasks511/splattotable.xml.rst	     )
# - [split		   ](../tasks511/split.xml.rst		     )
# - [spxfit		   ](../tasks511/spxfit.xml.rst		     )
# - [ssoflux		   ](../tasks511/ssoflux.xml.rst		     )
# - [statwt		   ](../tasks511/statwt.xml.rst		     )
# - [statwt2		   ](../tasks511/statwt2.xml.rst		     )
# - [tclean		   ](../tasks511/tclean.xml.rst		     )
# - [tclean2		   ](../tasks511/tclean2.xml.rst		     )
# - [testconcat	   ](../tasks511/testconcat.xml.rst	     )
# - [uvcontsub	   ](../tasks511/uvcontsub.xml.rst	     )
# - [uvcontsub3	   ](../tasks511/uvcontsub3.xml.rst	     )
# - [uvmodelfit	   ](../tasks511/uvmodelfit.xml.rst	     )
# - [uvsub		   ](../tasks511/uvsub.xml.rst		     )
# - [viewer		   ](../tasks511/viewer.xml.rst		     )
# - [virtualconcat	   ](../tasks511/virtualconcat.xml.rst	     )
# - [vishead		   ](../tasks511/vishead.xml.rst		     )
# - [visstat		   ](../tasks511/visstat.xml.rst		     )
# - [visstat2	   ](../tasks511/visstat2.xml.rst	     )
# - [visstatold	   ](../tasks511/visstatold.xml.rst	     )
# - [widebandpbcor	   ](../tasks511/widebandpbcor.xml.rst	     )
# - [widefield	   ](../tasks511/widefield.xml.rst	     )
# - [wvrgcal            ](../tasks511/wvrgcal.xml.rst              )
#
#
# ## Download
#
# Original XML files 5.1.1: [download here](https://drive.google.com/file/d/1tUdW8taryUb1Hnb41nmEuOfu2mlEfTsN/view?usp=drive_link)
