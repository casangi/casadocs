# %% [markdown]
# <a href="https://colab.research.google.com/github/casangi/casadocs/blob/CAS-14318/docs/notebooks/XML472.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # XML information CASA 4.7.2
#
# - [accum		   ](../tasks472/accum.xml.rst		  )
# - [applycal	   ](../tasks472/applycal.xml.rst	  )
# - [asdmsummary	   ](../tasks472/asdmsummary.xml.rst	  )
# - [autoclean	   ](../tasks472/autoclean.xml.rst	  )
# - [bandpass	   ](../tasks472/bandpass.xml.rst	  )
# - [blcal		   ](../tasks472/blcal.xml.rst		  )
# - [boxit		   ](../tasks472/boxit.xml.rst		  )
# - [browsetable	   ](../tasks472/browsetable.xml.rst	  )
# - [calstat		   ](../tasks472/calstat.xml.rst		  )
# - [caltabconvert	   ](../tasks472/caltabconvert.xml.rst	  )
# - [clean		   ](../tasks472/clean.xml.rst		  )
# - [clearcal	   ](../tasks472/clearcal.xml.rst	  )
# - [clearplot	   ](../tasks472/clearplot.xml.rst	  )
# - [clearstat	   ](../tasks472/clearstat.xml.rst	  )
# - [concat		   ](../tasks472/concat.xml.rst		  )
# - [conjugatevis	   ](../tasks472/conjugatevis.xml.rst	  )
# - [csvclean	   ](../tasks472/csvclean.xml.rst	  )
# - [cvel		   ](../tasks472/cvel.xml.rst		  )
# - [cvel2		   ](../tasks472/cvel2.xml.rst		  )
# - [deconvolve	   ](../tasks472/deconvolve.xml.rst	  )
# - [delmod		   ](../tasks472/delmod.xml.rst		  )
# - [exportasdm	   ](../tasks472/exportasdm.xml.rst	  )
# - [exportfits	   ](../tasks472/exportfits.xml.rst	  )
# - [exportuvfits	   ](../tasks472/exportuvfits.xml.rst	  )
# - [feather		   ](../tasks472/feather.xml.rst		  )
# - [find		   ](../tasks472/find.xml.rst		  )
# - [fixplanets	   ](../tasks472/fixplanets.xml.rst	  )
# - [fixvis		   ](../tasks472/fixvis.xml.rst		  )
# - [flagcmd		   ](../tasks472/flagcmd.xml.rst		  )
# - [flagdata	   ](../tasks472/flagdata.xml.rst	  )
# - [flagmanager	   ](../tasks472/flagmanager.xml.rst	  )
# - [fluxscale	   ](../tasks472/fluxscale.xml.rst	  )
# - [ft		   ](../tasks472/ft.xml.rst		  )
# - [gaincal		   ](../tasks472/gaincal.xml.rst		  )
# - [gencal		   ](../tasks472/gencal.xml.rst		  )
# - [hanningsmooth	   ](../tasks472/hanningsmooth.xml.rst	  )
# - [imcollapse	   ](../tasks472/imcollapse.xml.rst	  )
# - [imcontsub	   ](../tasks472/imcontsub.xml.rst	  )
# - [imfit		   ](../tasks472/imfit.xml.rst		  )
# - [imhead		   ](../tasks472/imhead.xml.rst		  )
# - [imhistory	   ](../tasks472/imhistory.xml.rst	  )
# - [immath		   ](../tasks472/immath.xml.rst		  )
# - [immoments	   ](../tasks472/immoments.xml.rst	  )
# - [impbcor		   ](../tasks472/impbcor.xml.rst		  )
# - [importasap	   ](../tasks472/importasap.xml.rst	  )
# - [importasdm	   ](../tasks472/importasdm.xml.rst	  )
# - [importatca	   ](../tasks472/importatca.xml.rst	  )
# - [importevla	   ](../tasks472/importevla.xml.rst	  )
# - [importfits	   ](../tasks472/importfits.xml.rst	  )
# - [importfitsidi	   ](../tasks472/importfitsidi.xml.rst	  )
# - [importgmrt	   ](../tasks472/importgmrt.xml.rst	  )
# - [importmiriad	   ](../tasks472/importmiriad.xml.rst	  )
# - [importnro	   ](../tasks472/importnro.xml.rst	  )
# - [importuvfits	   ](../tasks472/importuvfits.xml.rst	  )
# - [importvla	   ](../tasks472/importvla.xml.rst	  )
# - [impv		   ](../tasks472/impv.xml.rst		  )
# - [imrebin		   ](../tasks472/imrebin.xml.rst		  )
# - [imreframe	   ](../tasks472/imreframe.xml.rst	  )
# - [imregrid	   ](../tasks472/imregrid.xml.rst	  )
# - [imsmooth	   ](../tasks472/imsmooth.xml.rst	  )
# - [imstat		   ](../tasks472/imstat.xml.rst		  )
# - [imsubimage	   ](../tasks472/imsubimage.xml.rst	  )
# - [imtrans		   ](../tasks472/imtrans.xml.rst		  )
# - [imval		   ](../tasks472/imval.xml.rst		  )
# - [imview		   ](../tasks472/imview.xml.rst		  )
# - [initweights	   ](../tasks472/initweights.xml.rst	  )
# - [listcal		   ](../tasks472/listcal.xml.rst		  )
# - [listfits	   ](../tasks472/listfits.xml.rst	  )
# - [listhistory	   ](../tasks472/listhistory.xml.rst	  )
# - [listobs		   ](../tasks472/listobs.xml.rst		  )
# - [listpartition	   ](../tasks472/listpartition.xml.rst	  )
# - [listsdm		   ](../tasks472/listsdm.xml.rst		  )
# - [listvis		   ](../tasks472/listvis.xml.rst		  )
# - [makemask	   ](../tasks472/makemask.xml.rst	  )
# - [mosaic		   ](../tasks472/mosaic.xml.rst		  )
# - [mstransform	   ](../tasks472/mstransform.xml.rst	  )
# - [msuvbin		   ](../tasks472/msuvbin.xml.rst		  )
# - [msview		   ](../tasks472/msview.xml.rst		  )
# - [oldhanningsmooth   ](../tasks472/oldhanningsmooth.xml.rst  )
# - [oldsplit	   ](../tasks472/oldsplit.xml.rst	  )
# - [partition	   ](../tasks472/partition.xml.rst	  )
# - [plotants	   ](../tasks472/plotants.xml.rst	  )
# - [plotbandpass	   ](../tasks472/plotbandpass.xml.rst	  )
# - [plotcal		   ](../tasks472/plotcal.xml.rst		  )
# - [plotms		   ](../tasks472/plotms.xml.rst		  )
# - [plotprofilemap	   ](../tasks472/plotprofilemap.xml.rst	  )
# - [plotuv		   ](../tasks472/plotuv.xml.rst		  )
# - [plotweather	   ](../tasks472/plotweather.xml.rst	  )
# - [polcal		   ](../tasks472/polcal.xml.rst		  )
# - [predictcomp	   ](../tasks472/predictcomp.xml.rst	  )
# - [rmfit		   ](../tasks472/rmfit.xml.rst		  )
# - [rmtables	   ](../tasks472/rmtables.xml.rst	  )
# - [sdaverage	   ](../tasks472/sdaverage.xml.rst	  )
# - [sdbaseline	   ](../tasks472/sdbaseline.xml.rst	  )
# - [sdbaseline2	   ](../tasks472/sdbaseline2.xml.rst	  )
# - [sdcal		   ](../tasks472/sdcal.xml.rst		  )
# - [sdcal2		   ](../tasks472/sdcal2.xml.rst		  )
# - [sdcoadd		   ](../tasks472/sdcoadd.xml.rst		  )
# - [sdfit		   ](../tasks472/sdfit.xml.rst		  )
# - [sdflag		   ](../tasks472/sdflag.xml.rst		  )
# - [sdflagmanager	   ](../tasks472/sdflagmanager.xml.rst	  )
# - [sdgaincal	   ](../tasks472/sdgaincal.xml.rst	  )
# - [sdgrid		   ](../tasks472/sdgrid.xml.rst		  )
# - [sdimaging	   ](../tasks472/sdimaging.xml.rst	  )
# - [sdimprocess	   ](../tasks472/sdimprocess.xml.rst	  )
# - [sdlist		   ](../tasks472/sdlist.xml.rst		  )
# - [sdmath		   ](../tasks472/sdmath.xml.rst		  )
# - [sdplot		   ](../tasks472/sdplot.xml.rst		  )
# - [sdreduce	   ](../tasks472/sdreduce.xml.rst	  )
# - [sdsave		   ](../tasks472/sdsave.xml.rst		  )
# - [sdscale		   ](../tasks472/sdscale.xml.rst		  )
# - [sdstat		   ](../tasks472/sdstat.xml.rst		  )
# - [setjy		   ](../tasks472/setjy.xml.rst		  )
# - [simalma		   ](../tasks472/simalma.xml.rst		  )
# - [simanalyze	   ](../tasks472/simanalyze.xml.rst	  )
# - [simobserve	   ](../tasks472/simobserve.xml.rst	  )
# - [slsearch	   ](../tasks472/slsearch.xml.rst	  )
# - [smoothcal	   ](../tasks472/smoothcal.xml.rst	  )
# - [specfit		   ](../tasks472/specfit.xml.rst		  )
# - [specflux	   ](../tasks472/specflux.xml.rst	  )
# - [specsmooth	   ](../tasks472/specsmooth.xml.rst	  )
# - [splattotable	   ](../tasks472/splattotable.xml.rst	  )
# - [split		   ](../tasks472/split.xml.rst		  )
# - [spxfit		   ](../tasks472/spxfit.xml.rst		  )
# - [ssoflux		   ](../tasks472/ssoflux.xml.rst		  )
# - [statwt		   ](../tasks472/statwt.xml.rst		  )
# - [tclean		   ](../tasks472/tclean.xml.rst		  )
# - [tclean2		   ](../tasks472/tclean2.xml.rst		  )
# - [testconcat	   ](../tasks472/testconcat.xml.rst	  )
# - [tsdbaseline	   ](../tasks472/tsdbaseline.xml.rst	  )
# - [tsdcal		   ](../tasks472/tsdcal.xml.rst		  )
# - [tsdfit		   ](../tasks472/tsdfit.xml.rst		  )
# - [tsdsmooth	   ](../tasks472/tsdsmooth.xml.rst	  )
# - [uvcontsub	   ](../tasks472/uvcontsub.xml.rst	  )
# - [uvcontsub3	   ](../tasks472/uvcontsub3.xml.rst	  )
# - [uvmodelfit	   ](../tasks472/uvmodelfit.xml.rst	  )
# - [uvsub		   ](../tasks472/uvsub.xml.rst		  )
# - [viewer		   ](../tasks472/viewer.xml.rst		  )
# - [virtualconcat	   ](../tasks472/virtualconcat.xml.rst	  )
# - [vishead		   ](../tasks472/vishead.xml.rst		  )
# - [visstat		   ](../tasks472/visstat.xml.rst		  )
# - [visstat2	   ](../tasks472/visstat2.xml.rst	  )
# - [widebandpbcor	   ](../tasks472/widebandpbcor.xml.rst	  )
# - [widefield	   ](../tasks472/widefield.xml.rst	  )
# - [wvrgcal            ](../tasks472/wvrgcal.xml.rst           )
#
#
# ## Download
#
# Original XML files 4.7.2: [download here](https://drive.google.com/file/d/1tA7cc8gjRgJvcF7isk_ERQGUsywE-8tL/view?usp=drive_link)
