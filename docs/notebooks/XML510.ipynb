# %% [markdown]
# <a href="https://colab.research.google.com/github/casangi/casadocs/blob/CAS-14318/docs/notebooks/XML510.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # XML information CASA 5.1.0
#
# - [accum		   ](../tasks510/accum.xml.rst		     )
# - [applycal	   ](../tasks510/applycal.xml.rst	     )
# - [asdmsummary	   ](../tasks510/asdmsummary.xml.rst	     )
# - [autoclean	   ](../tasks510/autoclean.xml.rst	     )
# - [bandpass	   ](../tasks510/bandpass.xml.rst	     )
# - [blcal		   ](../tasks510/blcal.xml.rst		     )
# - [boxit		   ](../tasks510/boxit.xml.rst		     )
# - [browsetable	   ](../tasks510/browsetable.xml.rst	     )
# - [calstat		   ](../tasks510/calstat.xml.rst		     )
# - [caltabconvert	   ](../tasks510/caltabconvert.xml.rst	     )
# - [clean		   ](../tasks510/clean.xml.rst		     )
# - [clearcal	   ](../tasks510/clearcal.xml.rst	     )
# - [clearplot	   ](../tasks510/clearplot.xml.rst	     )
# - [clearstat	   ](../tasks510/clearstat.xml.rst	     )
# - [concat		   ](../tasks510/concat.xml.rst		     )
# - [conjugatevis	   ](../tasks510/conjugatevis.xml.rst	     )
# - [csvclean	   ](../tasks510/csvclean.xml.rst	     )
# - [cvel		   ](../tasks510/cvel.xml.rst		     )
# - [cvel2		   ](../tasks510/cvel2.xml.rst		     )
# - [deconvolve	   ](../tasks510/deconvolve.xml.rst	     )
# - [delmod		   ](../tasks510/delmod.xml.rst		     )
# - [exportasdm	   ](../tasks510/exportasdm.xml.rst	     )
# - [exportfits	   ](../tasks510/exportfits.xml.rst	     )
# - [exportuvfits	   ](../tasks510/exportuvfits.xml.rst	     )
# - [feather		   ](../tasks510/feather.xml.rst		     )
# - [find		   ](../tasks510/find.xml.rst		     )
# - [fixplanets	   ](../tasks510/fixplanets.xml.rst	     )
# - [fixvis		   ](../tasks510/fixvis.xml.rst		     )
# - [flagcmd		   ](../tasks510/flagcmd.xml.rst		     )
# - [flagdata	   ](../tasks510/flagdata.xml.rst	     )
# - [flagmanager	   ](../tasks510/flagmanager.xml.rst	     )
# - [fluxscale	   ](../tasks510/fluxscale.xml.rst	     )
# - [ft		   ](../tasks510/ft.xml.rst		     )
# - [gaincal		   ](../tasks510/gaincal.xml.rst		     )
# - [gencal		   ](../tasks510/gencal.xml.rst		     )
# - [hanningsmooth	   ](../tasks510/hanningsmooth.xml.rst	     )
# - [imcollapse	   ](../tasks510/imcollapse.xml.rst	     )
# - [imcontsub	   ](../tasks510/imcontsub.xml.rst	     )
# - [imdev		   ](../tasks510/imdev.xml.rst		     )
# - [imfit		   ](../tasks510/imfit.xml.rst		     )
# - [imhead		   ](../tasks510/imhead.xml.rst		     )
# - [imhistory	   ](../tasks510/imhistory.xml.rst	     )
# - [immath		   ](../tasks510/immath.xml.rst		     )
# - [immoments	   ](../tasks510/immoments.xml.rst	     )
# - [impbcor		   ](../tasks510/impbcor.xml.rst		     )
# - [importasap	   ](../tasks510/importasap.xml.rst	     )
# - [importasdm	   ](../tasks510/importasdm.xml.rst	     )
# - [importatca	   ](../tasks510/importatca.xml.rst	     )
# - [importevla	   ](../tasks510/importevla.xml.rst	     )
# - [importfits	   ](../tasks510/importfits.xml.rst	     )
# - [importfitsidi	   ](../tasks510/importfitsidi.xml.rst	     )
# - [importgmrt	   ](../tasks510/importgmrt.xml.rst	     )
# - [importmiriad	   ](../tasks510/importmiriad.xml.rst	     )
# - [importnro	   ](../tasks510/importnro.xml.rst	     )
# - [importuvfits	   ](../tasks510/importuvfits.xml.rst	     )
# - [importvla	   ](../tasks510/importvla.xml.rst	     )
# - [impv		   ](../tasks510/impv.xml.rst		     )
# - [imrebin		   ](../tasks510/imrebin.xml.rst		     )
# - [imreframe	   ](../tasks510/imreframe.xml.rst	     )
# - [imregrid	   ](../tasks510/imregrid.xml.rst	     )
# - [imsmooth	   ](../tasks510/imsmooth.xml.rst	     )
# - [imstat		   ](../tasks510/imstat.xml.rst		     )
# - [imsubimage	   ](../tasks510/imsubimage.xml.rst	     )
# - [imtrans		   ](../tasks510/imtrans.xml.rst		     )
# - [imval		   ](../tasks510/imval.xml.rst		     )
# - [imview		   ](../tasks510/imview.xml.rst		     )
# - [initweights	   ](../tasks510/initweights.xml.rst	     )
# - [listcal		   ](../tasks510/listcal.xml.rst		     )
# - [listfits	   ](../tasks510/listfits.xml.rst	     )
# - [listhistory	   ](../tasks510/listhistory.xml.rst	     )
# - [listobs		   ](../tasks510/listobs.xml.rst		     )
# - [listpartition	   ](../tasks510/listpartition.xml.rst	     )
# - [listsdm		   ](../tasks510/listsdm.xml.rst		     )
# - [listvis		   ](../tasks510/listvis.xml.rst		     )
# - [makemask	   ](../tasks510/makemask.xml.rst	     )
# - [mosaic		   ](../tasks510/mosaic.xml.rst		     )
# - [mstransform	   ](../tasks510/mstransform.xml.rst	     )
# - [msuvbin		   ](../tasks510/msuvbin.xml.rst		     )
# - [msview		   ](../tasks510/msview.xml.rst		     )
# - [oldhanningsmooth   ](../tasks510/oldhanningsmooth.xml.rst     )
# - [oldsplit	   ](../tasks510/oldsplit.xml.rst	     )
# - [partition	   ](../tasks510/partition.xml.rst	     )
# - [plotants	   ](../tasks510/plotants.xml.rst	     )
# - [plotbandpass	   ](../tasks510/plotbandpass.xml.rst	     )
# - [plotcal		   ](../tasks510/plotcal.xml.rst		     )
# - [plotms		   ](../tasks510/plotms.xml.rst		     )
# - [plotprofilemap	   ](../tasks510/plotprofilemap.xml.rst	     )
# - [plotuv		   ](../tasks510/plotuv.xml.rst		     )
# - [plotweather	   ](../tasks510/plotweather.xml.rst	     )
# - [polcal		   ](../tasks510/polcal.xml.rst		     )
# - [predictcomp	   ](../tasks510/predictcomp.xml.rst	     )
# - [rerefant	   ](../tasks510/rerefant.xml.rst	     )
# - [rmfit		   ](../tasks510/rmfit.xml.rst		     )
# - [rmtables	   ](../tasks510/rmtables.xml.rst	     )
# - [sdbaseline	   ](../tasks510/sdbaseline.xml.rst	     )
# - [sdcal		   ](../tasks510/sdcal.xml.rst		     )
# - [sdfit		   ](../tasks510/sdfit.xml.rst		     )
# - [sdfixscan	   ](../tasks510/sdfixscan.xml.rst	     )
# - [sdgaincal	   ](../tasks510/sdgaincal.xml.rst	     )
# - [sdimaging	   ](../tasks510/sdimaging.xml.rst	     )
# - [sdsmooth	   ](../tasks510/sdsmooth.xml.rst	     )
# - [setjy		   ](../tasks510/setjy.xml.rst		     )
# - [simalma		   ](../tasks510/simalma.xml.rst		     )
# - [simanalyze	   ](../tasks510/simanalyze.xml.rst	     )
# - [simobserve	   ](../tasks510/simobserve.xml.rst	     )
# - [slsearch	   ](../tasks510/slsearch.xml.rst	     )
# - [smoothcal	   ](../tasks510/smoothcal.xml.rst	     )
# - [specfit		   ](../tasks510/specfit.xml.rst		     )
# - [specflux	   ](../tasks510/specflux.xml.rst	     )
# - [specsmooth	   ](../tasks510/specsmooth.xml.rst	     )
# - [splattotable	   ](../tasks510/splattotable.xml.rst	     )
# - [split		   ](../tasks510/split.xml.rst		     )
# - [spxfit		   ](../tasks510/spxfit.xml.rst		     )
# - [ssoflux		   ](../tasks510/ssoflux.xml.rst		     )
# - [statwt		   ](../tasks510/statwt.xml.rst		     )
# - [statwt2		   ](../tasks510/statwt2.xml.rst		     )
# - [tclean		   ](../tasks510/tclean.xml.rst		     )
# - [tclean2		   ](../tasks510/tclean2.xml.rst		     )
# - [testconcat	   ](../tasks510/testconcat.xml.rst	     )
# - [uvcontsub	   ](../tasks510/uvcontsub.xml.rst	     )
# - [uvcontsub3	   ](../tasks510/uvcontsub3.xml.rst	     )
# - [uvmodelfit	   ](../tasks510/uvmodelfit.xml.rst	     )
# - [uvsub		   ](../tasks510/uvsub.xml.rst		     )
# - [viewer		   ](../tasks510/viewer.xml.rst		     )
# - [virtualconcat	   ](../tasks510/virtualconcat.xml.rst	     )
# - [vishead		   ](../tasks510/vishead.xml.rst		     )
# - [visstat		   ](../tasks510/visstat.xml.rst		     )
# - [visstat2	   ](../tasks510/visstat2.xml.rst	     )
# - [visstatold	   ](../tasks510/visstatold.xml.rst	     )
# - [widebandpbcor	   ](../tasks510/widebandpbcor.xml.rst	     )
# - [widefield	   ](../tasks510/widefield.xml.rst	     )
# - [wvrgcal            ](../tasks510/wvrgcal.xml.rst              )
#
#
# ## Download
#
# Original XML files 5.1.0: [download here](https://drive.google.com/file/d/1yNq3_y-z3zZnv5Gb37XyUb3j8ekXpxyQ/view?usp=drive_link)
