# %% [markdown]
# <a href="https://colab.research.google.com/github/casangi/casadocs/blob/CAS-14318/docs/notebooks/XML471.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # XML information CASA 4.7.1
#
# - [accum		   ](../tasks471/accum.xml.rst		  )
# - [applycal	   ](../tasks471/applycal.xml.rst	  )
# - [asdmsummary	   ](../tasks471/asdmsummary.xml.rst	  )
# - [autoclean	   ](../tasks471/autoclean.xml.rst	  )
# - [bandpass	   ](../tasks471/bandpass.xml.rst	  )
# - [blcal		   ](../tasks471/blcal.xml.rst		  )
# - [boxit		   ](../tasks471/boxit.xml.rst		  )
# - [browsetable	   ](../tasks471/browsetable.xml.rst	  )
# - [calstat		   ](../tasks471/calstat.xml.rst		  )
# - [caltabconvert	   ](../tasks471/caltabconvert.xml.rst	  )
# - [clean		   ](../tasks471/clean.xml.rst		  )
# - [clearcal	   ](../tasks471/clearcal.xml.rst	  )
# - [clearplot	   ](../tasks471/clearplot.xml.rst	  )
# - [clearstat	   ](../tasks471/clearstat.xml.rst	  )
# - [concat		   ](../tasks471/concat.xml.rst		  )
# - [conjugatevis	   ](../tasks471/conjugatevis.xml.rst	  )
# - [csvclean	   ](../tasks471/csvclean.xml.rst	  )
# - [cvel		   ](../tasks471/cvel.xml.rst		  )
# - [cvel2		   ](../tasks471/cvel2.xml.rst		  )
# - [deconvolve	   ](../tasks471/deconvolve.xml.rst	  )
# - [delmod		   ](../tasks471/delmod.xml.rst		  )
# - [exportasdm	   ](../tasks471/exportasdm.xml.rst	  )
# - [exportfits	   ](../tasks471/exportfits.xml.rst	  )
# - [exportuvfits	   ](../tasks471/exportuvfits.xml.rst	  )
# - [feather		   ](../tasks471/feather.xml.rst		  )
# - [find		   ](../tasks471/find.xml.rst		  )
# - [fixplanets	   ](../tasks471/fixplanets.xml.rst	  )
# - [fixvis		   ](../tasks471/fixvis.xml.rst		  )
# - [flagcmd		   ](../tasks471/flagcmd.xml.rst		  )
# - [flagdata	   ](../tasks471/flagdata.xml.rst	  )
# - [flagmanager	   ](../tasks471/flagmanager.xml.rst	  )
# - [fluxscale	   ](../tasks471/fluxscale.xml.rst	  )
# - [ft		   ](../tasks471/ft.xml.rst		  )
# - [gaincal		   ](../tasks471/gaincal.xml.rst		  )
# - [gencal		   ](../tasks471/gencal.xml.rst		  )
# - [hanningsmooth	   ](../tasks471/hanningsmooth.xml.rst	  )
# - [imcollapse	   ](../tasks471/imcollapse.xml.rst	  )
# - [imcontsub	   ](../tasks471/imcontsub.xml.rst	  )
# - [imfit		   ](../tasks471/imfit.xml.rst		  )
# - [imhead		   ](../tasks471/imhead.xml.rst		  )
# - [imhistory	   ](../tasks471/imhistory.xml.rst	  )
# - [immath		   ](../tasks471/immath.xml.rst		  )
# - [immoments	   ](../tasks471/immoments.xml.rst	  )
# - [impbcor		   ](../tasks471/impbcor.xml.rst		  )
# - [importasap	   ](../tasks471/importasap.xml.rst	  )
# - [importasdm	   ](../tasks471/importasdm.xml.rst	  )
# - [importatca	   ](../tasks471/importatca.xml.rst	  )
# - [importevla	   ](../tasks471/importevla.xml.rst	  )
# - [importfits	   ](../tasks471/importfits.xml.rst	  )
# - [importfitsidi	   ](../tasks471/importfitsidi.xml.rst	  )
# - [importgmrt	   ](../tasks471/importgmrt.xml.rst	  )
# - [importmiriad	   ](../tasks471/importmiriad.xml.rst	  )
# - [importnro	   ](../tasks471/importnro.xml.rst	  )
# - [importuvfits	   ](../tasks471/importuvfits.xml.rst	  )
# - [importvla	   ](../tasks471/importvla.xml.rst	  )
# - [impv		   ](../tasks471/impv.xml.rst		  )
# - [imrebin		   ](../tasks471/imrebin.xml.rst		  )
# - [imreframe	   ](../tasks471/imreframe.xml.rst	  )
# - [imregrid	   ](../tasks471/imregrid.xml.rst	  )
# - [imsmooth	   ](../tasks471/imsmooth.xml.rst	  )
# - [imstat		   ](../tasks471/imstat.xml.rst		  )
# - [imsubimage	   ](../tasks471/imsubimage.xml.rst	  )
# - [imtrans		   ](../tasks471/imtrans.xml.rst		  )
# - [imval		   ](../tasks471/imval.xml.rst		  )
# - [imview		   ](../tasks471/imview.xml.rst		  )
# - [initweights	   ](../tasks471/initweights.xml.rst	  )
# - [listcal		   ](../tasks471/listcal.xml.rst		  )
# - [listfits	   ](../tasks471/listfits.xml.rst	  )
# - [listhistory	   ](../tasks471/listhistory.xml.rst	  )
# - [listobs		   ](../tasks471/listobs.xml.rst		  )
# - [listpartition	   ](../tasks471/listpartition.xml.rst	  )
# - [listsdm		   ](../tasks471/listsdm.xml.rst		  )
# - [listvis		   ](../tasks471/listvis.xml.rst		  )
# - [makemask	   ](../tasks471/makemask.xml.rst	  )
# - [mosaic		   ](../tasks471/mosaic.xml.rst		  )
# - [mstransform	   ](../tasks471/mstransform.xml.rst	  )
# - [msuvbin		   ](../tasks471/msuvbin.xml.rst		  )
# - [msview		   ](../tasks471/msview.xml.rst		  )
# - [oldhanningsmooth   ](../tasks471/oldhanningsmooth.xml.rst  )
# - [oldsplit	   ](../tasks471/oldsplit.xml.rst	  )
# - [partition	   ](../tasks471/partition.xml.rst	  )
# - [plotants	   ](../tasks471/plotants.xml.rst	  )
# - [plotbandpass	   ](../tasks471/plotbandpass.xml.rst	  )
# - [plotcal		   ](../tasks471/plotcal.xml.rst		  )
# - [plotms		   ](../tasks471/plotms.xml.rst		  )
# - [plotprofilemap	   ](../tasks471/plotprofilemap.xml.rst	  )
# - [plotuv		   ](../tasks471/plotuv.xml.rst		  )
# - [plotweather	   ](../tasks471/plotweather.xml.rst	  )
# - [polcal		   ](../tasks471/polcal.xml.rst		  )
# - [predictcomp	   ](../tasks471/predictcomp.xml.rst	  )
# - [rmfit		   ](../tasks471/rmfit.xml.rst		  )
# - [rmtables	   ](../tasks471/rmtables.xml.rst	  )
# - [sdaverage	   ](../tasks471/sdaverage.xml.rst	  )
# - [sdbaseline	   ](../tasks471/sdbaseline.xml.rst	  )
# - [sdbaseline2	   ](../tasks471/sdbaseline2.xml.rst	  )
# - [sdcal		   ](../tasks471/sdcal.xml.rst		  )
# - [sdcal2		   ](../tasks471/sdcal2.xml.rst		  )
# - [sdcoadd		   ](../tasks471/sdcoadd.xml.rst		  )
# - [sdfit		   ](../tasks471/sdfit.xml.rst		  )
# - [sdflag		   ](../tasks471/sdflag.xml.rst		  )
# - [sdflagmanager	   ](../tasks471/sdflagmanager.xml.rst	  )
# - [sdgaincal	   ](../tasks471/sdgaincal.xml.rst	  )
# - [sdgrid		   ](../tasks471/sdgrid.xml.rst		  )
# - [sdimaging	   ](../tasks471/sdimaging.xml.rst	  )
# - [sdimprocess	   ](../tasks471/sdimprocess.xml.rst	  )
# - [sdlist		   ](../tasks471/sdlist.xml.rst		  )
# - [sdmath		   ](../tasks471/sdmath.xml.rst		  )
# - [sdplot		   ](../tasks471/sdplot.xml.rst		  )
# - [sdreduce	   ](../tasks471/sdreduce.xml.rst	  )
# - [sdsave		   ](../tasks471/sdsave.xml.rst		  )
# - [sdscale		   ](../tasks471/sdscale.xml.rst		  )
# - [sdstat		   ](../tasks471/sdstat.xml.rst		  )
# - [setjy		   ](../tasks471/setjy.xml.rst		  )
# - [simalma		   ](../tasks471/simalma.xml.rst		  )
# - [simanalyze	   ](../tasks471/simanalyze.xml.rst	  )
# - [simobserve	   ](../tasks471/simobserve.xml.rst	  )
# - [slsearch	   ](../tasks471/slsearch.xml.rst	  )
# - [smoothcal	   ](../tasks471/smoothcal.xml.rst	  )
# - [specfit		   ](../tasks471/specfit.xml.rst		  )
# - [specflux	   ](../tasks471/specflux.xml.rst	  )
# - [specsmooth	   ](../tasks471/specsmooth.xml.rst	  )
# - [splattotable	   ](../tasks471/splattotable.xml.rst	  )
# - [split		   ](../tasks471/split.xml.rst		  )
# - [spxfit		   ](../tasks471/spxfit.xml.rst		  )
# - [ssoflux		   ](../tasks471/ssoflux.xml.rst		  )
# - [statwt		   ](../tasks471/statwt.xml.rst		  )
# - [tclean		   ](../tasks471/tclean.xml.rst		  )
# - [tclean2		   ](../tasks471/tclean2.xml.rst		  )
# - [testconcat	   ](../tasks471/testconcat.xml.rst	  )
# - [tsdbaseline	   ](../tasks471/tsdbaseline.xml.rst	  )
# - [tsdcal		   ](../tasks471/tsdcal.xml.rst		  )
# - [tsdfit		   ](../tasks471/tsdfit.xml.rst		  )
# - [tsdsmooth	   ](../tasks471/tsdsmooth.xml.rst	  )
# - [uvcontsub	   ](../tasks471/uvcontsub.xml.rst	  )
# - [uvcontsub3	   ](../tasks471/uvcontsub3.xml.rst	  )
# - [uvmodelfit	   ](../tasks471/uvmodelfit.xml.rst	  )
# - [uvsub		   ](../tasks471/uvsub.xml.rst		  )
# - [viewer		   ](../tasks471/viewer.xml.rst		  )
# - [virtualconcat	   ](../tasks471/virtualconcat.xml.rst	  )
# - [vishead		   ](../tasks471/vishead.xml.rst		  )
# - [visstat		   ](../tasks471/visstat.xml.rst		  )
# - [visstat2	   ](../tasks471/visstat2.xml.rst	  )
# - [widebandpbcor	   ](../tasks471/widebandpbcor.xml.rst	  )
# - [widefield	   ](../tasks471/widefield.xml.rst	  )
# - [wvrgcal	   ](../tasks471/wvrgcal.xml.rst )
#
#
# ## Download
#
# Original XML files 4.7.1: [download here](https://drive.google.com/file/d/1SvI4luO4aHZu3wTVm5Xqmh_CCh4hsYLa/view?usp=drive_link)
