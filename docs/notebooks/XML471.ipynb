# %% [markdown]
# <a href="https://colab.research.google.com/github/casangi/casadocs/blob/CAS-14318/docs/notebooks/XML471.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # XML information CASA 4.7.1
#
# - [accum		   ](../tasks470/accum.xml.rst		  )
# - [applycal	   ](../tasks470/applycal.xml.rst	  )
# - [asdmsummary	   ](../tasks470/asdmsummary.xml.rst	  )
# - [autoclean	   ](../tasks470/autoclean.xml.rst	  )
# - [bandpass	   ](../tasks470/bandpass.xml.rst	  )
# - [blcal		   ](../tasks470/blcal.xml.rst		  )
# - [boxit		   ](../tasks470/boxit.xml.rst		  )
# - [browsetable	   ](../tasks470/browsetable.xml.rst	  )
# - [calstat		   ](../tasks470/calstat.xml.rst		  )
# - [caltabconvert	   ](../tasks470/caltabconvert.xml.rst	  )
# - [clean		   ](../tasks470/clean.xml.rst		  )
# - [clearcal	   ](../tasks470/clearcal.xml.rst	  )
# - [clearplot	   ](../tasks470/clearplot.xml.rst	  )
# - [clearstat	   ](../tasks470/clearstat.xml.rst	  )
# - [concat		   ](../tasks470/concat.xml.rst		  )
# - [conjugatevis	   ](../tasks470/conjugatevis.xml.rst	  )
# - [csvclean	   ](../tasks470/csvclean.xml.rst	  )
# - [cvel		   ](../tasks470/cvel.xml.rst		  )
# - [cvel2		   ](../tasks470/cvel2.xml.rst		  )
# - [deconvolve	   ](../tasks470/deconvolve.xml.rst	  )
# - [delmod		   ](../tasks470/delmod.xml.rst		  )
# - [exportasdm	   ](../tasks470/exportasdm.xml.rst	  )
# - [exportfits	   ](../tasks470/exportfits.xml.rst	  )
# - [exportuvfits	   ](../tasks470/exportuvfits.xml.rst	  )
# - [feather		   ](../tasks470/feather.xml.rst		  )
# - [find		   ](../tasks470/find.xml.rst		  )
# - [fixplanets	   ](../tasks470/fixplanets.xml.rst	  )
# - [fixvis		   ](../tasks470/fixvis.xml.rst		  )
# - [flagcmd		   ](../tasks470/flagcmd.xml.rst		  )
# - [flagdata	   ](../tasks470/flagdata.xml.rst	  )
# - [flagmanager	   ](../tasks470/flagmanager.xml.rst	  )
# - [fluxscale	   ](../tasks470/fluxscale.xml.rst	  )
# - [ft		   ](../tasks470/ft.xml.rst		  )
# - [gaincal		   ](../tasks470/gaincal.xml.rst		  )
# - [gencal		   ](../tasks470/gencal.xml.rst		  )
# - [hanningsmooth	   ](../tasks470/hanningsmooth.xml.rst	  )
# - [imcollapse	   ](../tasks470/imcollapse.xml.rst	  )
# - [imcontsub	   ](../tasks470/imcontsub.xml.rst	  )
# - [imfit		   ](../tasks470/imfit.xml.rst		  )
# - [imhead		   ](../tasks470/imhead.xml.rst		  )
# - [imhistory	   ](../tasks470/imhistory.xml.rst	  )
# - [immath		   ](../tasks470/immath.xml.rst		  )
# - [immoments	   ](../tasks470/immoments.xml.rst	  )
# - [impbcor		   ](../tasks470/impbcor.xml.rst		  )
# - [importasap	   ](../tasks470/importasap.xml.rst	  )
# - [importasdm	   ](../tasks470/importasdm.xml.rst	  )
# - [importatca	   ](../tasks470/importatca.xml.rst	  )
# - [importevla	   ](../tasks470/importevla.xml.rst	  )
# - [importfits	   ](../tasks470/importfits.xml.rst	  )
# - [importfitsidi	   ](../tasks470/importfitsidi.xml.rst	  )
# - [importgmrt	   ](../tasks470/importgmrt.xml.rst	  )
# - [importmiriad	   ](../tasks470/importmiriad.xml.rst	  )
# - [importnro	   ](../tasks470/importnro.xml.rst	  )
# - [importuvfits	   ](../tasks470/importuvfits.xml.rst	  )
# - [importvla	   ](../tasks470/importvla.xml.rst	  )
# - [impv		   ](../tasks470/impv.xml.rst		  )
# - [imrebin		   ](../tasks470/imrebin.xml.rst		  )
# - [imreframe	   ](../tasks470/imreframe.xml.rst	  )
# - [imregrid	   ](../tasks470/imregrid.xml.rst	  )
# - [imsmooth	   ](../tasks470/imsmooth.xml.rst	  )
# - [imstat		   ](../tasks470/imstat.xml.rst		  )
# - [imsubimage	   ](../tasks470/imsubimage.xml.rst	  )
# - [imtrans		   ](../tasks470/imtrans.xml.rst		  )
# - [imval		   ](../tasks470/imval.xml.rst		  )
# - [imview		   ](../tasks470/imview.xml.rst		  )
# - [initweights	   ](../tasks470/initweights.xml.rst	  )
# - [listcal		   ](../tasks470/listcal.xml.rst		  )
# - [listfits	   ](../tasks470/listfits.xml.rst	  )
# - [listhistory	   ](../tasks470/listhistory.xml.rst	  )
# - [listobs		   ](../tasks470/listobs.xml.rst		  )
# - [listpartition	   ](../tasks470/listpartition.xml.rst	  )
# - [listsdm		   ](../tasks470/listsdm.xml.rst		  )
# - [listvis		   ](../tasks470/listvis.xml.rst		  )
# - [makemask	   ](../tasks470/makemask.xml.rst	  )
# - [mosaic		   ](../tasks470/mosaic.xml.rst		  )
# - [mstransform	   ](../tasks470/mstransform.xml.rst	  )
# - [msuvbin		   ](../tasks470/msuvbin.xml.rst		  )
# - [msview		   ](../tasks470/msview.xml.rst		  )
# - [oldhanningsmooth   ](../tasks470/oldhanningsmooth.xml.rst  )
# - [oldsplit	   ](../tasks470/oldsplit.xml.rst	  )
# - [partition	   ](../tasks470/partition.xml.rst	  )
# - [plotants	   ](../tasks470/plotants.xml.rst	  )
# - [plotbandpass	   ](../tasks470/plotbandpass.xml.rst	  )
# - [plotcal		   ](../tasks470/plotcal.xml.rst		  )
# - [plotms		   ](../tasks470/plotms.xml.rst		  )
# - [plotprofilemap	   ](../tasks470/plotprofilemap.xml.rst	  )
# - [plotuv		   ](../tasks470/plotuv.xml.rst		  )
# - [plotweather	   ](../tasks470/plotweather.xml.rst	  )
# - [polcal		   ](../tasks470/polcal.xml.rst		  )
# - [predictcomp	   ](../tasks470/predictcomp.xml.rst	  )
# - [rmfit		   ](../tasks470/rmfit.xml.rst		  )
# - [rmtables	   ](../tasks470/rmtables.xml.rst	  )
# - [sdaverage	   ](../tasks470/sdaverage.xml.rst	  )
# - [sdbaseline	   ](../tasks470/sdbaseline.xml.rst	  )
# - [sdbaseline2	   ](../tasks470/sdbaseline2.xml.rst	  )
# - [sdcal		   ](../tasks470/sdcal.xml.rst		  )
# - [sdcal2		   ](../tasks470/sdcal2.xml.rst		  )
# - [sdcoadd		   ](../tasks470/sdcoadd.xml.rst		  )
# - [sdfit		   ](../tasks470/sdfit.xml.rst		  )
# - [sdflag		   ](../tasks470/sdflag.xml.rst		  )
# - [sdflagmanager	   ](../tasks470/sdflagmanager.xml.rst	  )
# - [sdgaincal	   ](../tasks470/sdgaincal.xml.rst	  )
# - [sdgrid		   ](../tasks470/sdgrid.xml.rst		  )
# - [sdimaging	   ](../tasks470/sdimaging.xml.rst	  )
# - [sdimprocess	   ](../tasks470/sdimprocess.xml.rst	  )
# - [sdlist		   ](../tasks470/sdlist.xml.rst		  )
# - [sdmath		   ](../tasks470/sdmath.xml.rst		  )
# - [sdplot		   ](../tasks470/sdplot.xml.rst		  )
# - [sdreduce	   ](../tasks470/sdreduce.xml.rst	  )
# - [sdsave		   ](../tasks470/sdsave.xml.rst		  )
# - [sdscale		   ](../tasks470/sdscale.xml.rst		  )
# - [sdstat		   ](../tasks470/sdstat.xml.rst		  )
# - [setjy		   ](../tasks470/setjy.xml.rst		  )
# - [simalma		   ](../tasks470/simalma.xml.rst		  )
# - [simanalyze	   ](../tasks470/simanalyze.xml.rst	  )
# - [simobserve	   ](../tasks470/simobserve.xml.rst	  )
# - [slsearch	   ](../tasks470/slsearch.xml.rst	  )
# - [smoothcal	   ](../tasks470/smoothcal.xml.rst	  )
# - [specfit		   ](../tasks470/specfit.xml.rst		  )
# - [specflux	   ](../tasks470/specflux.xml.rst	  )
# - [specsmooth	   ](../tasks470/specsmooth.xml.rst	  )
# - [splattotable	   ](../tasks470/splattotable.xml.rst	  )
# - [split		   ](../tasks470/split.xml.rst		  )
# - [spxfit		   ](../tasks470/spxfit.xml.rst		  )
# - [ssoflux		   ](../tasks470/ssoflux.xml.rst		  )
# - [statwt		   ](../tasks470/statwt.xml.rst		  )
# - [tclean		   ](../tasks470/tclean.xml.rst		  )
# - [tclean2		   ](../tasks470/tclean2.xml.rst		  )
# - [testconcat	   ](../tasks470/testconcat.xml.rst	  )
# - [tsdbaseline	   ](../tasks470/tsdbaseline.xml.rst	  )
# - [tsdcal		   ](../tasks470/tsdcal.xml.rst		  )
# - [tsdfit		   ](../tasks470/tsdfit.xml.rst		  )
# - [tsdsmooth	   ](../tasks470/tsdsmooth.xml.rst	  )
# - [uvcontsub	   ](../tasks470/uvcontsub.xml.rst	  )
# - [uvcontsub3	   ](../tasks470/uvcontsub3.xml.rst	  )
# - [uvmodelfit	   ](../tasks470/uvmodelfit.xml.rst	  )
# - [uvsub		   ](../tasks470/uvsub.xml.rst		  )
# - [viewer		   ](../tasks470/viewer.xml.rst		  )
# - [virtualconcat	   ](../tasks470/virtualconcat.xml.rst	  )
# - [vishead		   ](../tasks470/vishead.xml.rst		  )
# - [visstat		   ](../tasks470/visstat.xml.rst		  )
# - [visstat2	   ](../tasks470/visstat2.xml.rst	  )
# - [widebandpbcor	   ](../tasks470/widebandpbcor.xml.rst	  )
# - [widefield	   ](../tasks470/widefield.xml.rst	  )
# - [wvrgcal            ](../tasks470/wvrgcal.xml.rst           )
#
#
# ## Download
#
# Original XML files 4.7.1: [download here](https://drive.google.com/file/d/1SvI4luO4aHZu3wTVm5Xqmh_CCh4hsYLa/view?usp=drive_link)
