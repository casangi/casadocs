# %% [markdown]
# # Overview
#
# Overview of Visibility Data Import Export chapter
#
# To use CASA to process your data, you
# first will need to get it into a form that is understood by the package.
# These are &ldquo;MeasurementSets&rdquo; for synthesis and single dish
# data, which is the purpose of this chapter. Importing images,
# or&nbsp;&ldquo;image tables&rdquo; as understood by CASA, is explained
# [here](https://casa.nrao.edu/casadocs-devel/stable/imaging/image-analysis/image-import-and-export).
#
# There are a number of tasks used to fill
# telescope-specific data and to import/export standard formats. These
# are:
#
# -   **importasdm** &mdash; import of ALMA
#     data in ASDM format
# -   **importuvfits** &mdash; import
#     visibility data in UVFITS format
# -   **importfitsidi** &mdash; import
#     visibility data in the FITS-IDI format
# -   **importvla** &mdash; import data
#     from VLA that is in export format
# -   **importmiriad** &mdash; import data
#     from MIRIAD visibilities
# -   **importatca** &mdash; import ATCA
#     data that is in the RPFITS (archive) format
# -   **importgmrt**&nbsp;&mdash; import
#     GMRT&nbsp;data
# -   **importasap**&nbsp;&mdash;&nbsp;convert ASAP&nbsp;(ATNF
#     Spectral Analysis Package) into a CASA visibility data format
# -   **importnro**&nbsp;&mdash; import NRO
#     45m&nbsp;data&nbsp;
# -   **exportasdm**&nbsp;&mdash;&nbsp;convert a
#     CASA MS&nbsp;into an&nbsp;ASDM
# -   **exportuvfits** &mdash; export a
#     CASA MS in UVFITS format
