# %% [markdown]
# # Physical Units
#
# Physical Units recognized by CASA
#
# CASA regonizes physical units as listed in the following Tables.
#
# | Prefix | Name    | Value                  |
# |:-------|:--------|:-----------------------|
# | Y      | (yotta) | 10<sup>24</sup>        |
# | Z      | (zetta) | 10<sup>21</sup>        |
# | E      | (exa)   | 10<sup>18</sup>        |
# | P      | (peta)  | 10<sup>15</sup>        |
# | T      | (tera)  | 10<sup>12</sup>        |
# | G      | (giga)  | 10<sup>9</sup>         |
# | M      | (mega)  | 10<sup>6</sup>         |
# | k      | (kilo)  | 10<sup>3</sup>         |
# | h      | (hecto) | 10<sup>2</sup>         |
# | da     | (deka)  | 10                     |
# | d      | (deci)  | 10<sup>&minus;1</sup>  |
# | c      | (centi) | 10<sup>&minus;2</sup>  |
# | m      | (milli) | 10<sup>&minus;3</sup>  |
# | u      | (micro) | 10<sup>&minus;6</sup>  |
# | n      | (nano)  | 10<sup>&minus;9</sup>  |
# | p      | (pico)  | 10<sup>&minus;12</sup> |
# | f      | (femto) | 10<sup>&minus;15</sup> |
# | a      | (atto)  | 10<sup>&minus;18</sup> |
# | z      | (zepto) | 10<sup>&minus;21</sup> |
# | y      | (yocto) | 10<sup>&minus;24</sup> |
#
# |         |                            |
# |:--------|----------------------------|
# | Type    | Table                      |
# | ID      | reference-tab-prefix&nbsp; |
# | Caption | Physical units: Prefixes   |
#
# &nbsp;&nbsp;
#
# | Unit   | Name                | Value                                                                                   |
# |:-------|:--------------------|:----------------------------------------------------------------------------------------|
# | \$     | (currency)          | 1 \_                                                                                    |
# | %      | (percent)           | 0.01                                                                                    |
# | %%     | (permille)          | 0.001                                                                                   |
# | A      | (ampere)            | 1&nbsp;A                                                                                |
# | AE     | (astronomical unit) | 149597870659&nbsp;m                                                                     |
# | AU     | (astronomical unit) | 149597870659&nbsp;m                                                                     |
# | Bq     | (becquerel)         | 1 s<sup>&minus;1</sup>                                                                  |
# | C      | (coulomb)           | 1 s&nbsp;A                                                                              |
# | F      | (farad)             | 1 m<sup>&minus;2</sup>&nbsp;kg<sup>&minus;1</sup>&nbsp;s<sup>4</sup>&nbsp;A<sup>2</sup> |
# | Gy     | (gray)              | 1 m<sup>2</sup>&nbsp;s<sup>&minus;2</sup>                                               |
# | H      | (henry)             | 1 m<sup>2</sup>&nbsp;kg&nbsp;s<sup>&minus;2</sup>&nbsp;A<sup>&minus;2</sup>             |
# | Hz     | (hertz)             | 1 s<sup>&minus;1</sup>                                                                  |
# | J      | (joule)             | 1 m<sup>2</sup>&nbsp;kg&nbsp;s<sup>&minus;2</sup>                                       |
# | Jy     | (jansky)            | 10<sup>&minus;26</sup>&nbsp;kg&nbsp;s<sup>&minus;2</sup>                                |
# | K      | (kelvin)            | 1 K                                                                                     |
# | L      | (litre)             | 0.001 m<sup>3</sup>                                                                     |
# | M0     | (solar mass)        | 1.98891944407&times; 10<sup>30</sup>&nbsp;kg                                            |
# | N      | (newton)            | 1 m&nbsp;kg&nbsp;s<sup>&minus;2</sup>                                                   |
# | Ohm    | (ohm)               | 1 m<sup>2</sup>&nbsp;kg&nbsp;s<sup>&minus;3</sup>&nbsp;A<sup>&minus;2</sup>             |
# | Pa     | (pascal)            | 1 m<sup>&minus;1</sup>&nbsp;kg&nbsp;s<sup>&minus;2</sup>                                |
# | S      | (siemens)           | 1 m<sup>&minus;2</sup>&nbsp;kg<sup>&minus;1</sup>&nbsp;s<sup>3</sup>&nbsp;A<sup>2</sup> |
# | S0     | (solar mass)        | 1.98891944407&times; 10<sup>30</sup>&nbsp;kg                                            |
# | Sv     | (sievert)           | 1 m<sup>2</sup>&nbsp;s<sup>&minus;2</sup>                                               |
# | T      | (tesla)             | 1 kg&nbsp;s<sup>&minus;2</sup>&nbsp;A<sup>&minus;1</sup>                                |
# | UA     | (astronomical unit) | 149597870659&nbsp;m                                                                     |
# | V      | (volt)              | 1 m<sup>2</sup>&nbsp;kg&nbsp;s<sup>&minus;3</sup>&nbsp;A<sup>&minus;1</sup>             |
# | W      | (watt)              | 1 m<sup>2</sup>&nbsp;kg&nbsp;s<sup>&minus;3</sup>                                       |
# | Wb     | (weber)             | 1 m<sup>2</sup>&nbsp;kg&nbsp;s<sup>&minus;2</sup>&nbsp;A<sup>&minus;1</sup>             |
# | \_     | (undimensioned)     | 1 \_                                                                                    |
# | a      | (year)              | 31557600&nbsp;s                                                                         |
# | arcmin | (arcmin)            | 0.000290888208666&nbsp;rad                                                              |
# | arcsec | (arcsec)            | 4.8481368111&times;10<sup>&minus;6</sup>&nbsp;rad                                       |
# | as     | (arcsec)            | 4.8481368111e&times;10<sup>&minus;6</sup>&nbsp;rad                                      |
# | cd     | (candela)           | 1 cd                                                                                    |
# | cy     | (century)           | 3155760000 s                                                                            |
# | d      | (day)               | 86400 s                                                                                 |
# | deg    | (degree)            | 0.0174532925199 rad                                                                     |
# | g      | (gram)              | 0.001 kg                                                                                |
# | h      | (hour)              | 3600 s                                                                                  |
# | l      | (litre)             | 0.001 m<sup>3</sup>                                                                     |
# | lm     | (lumen)             | 1 cd&nbsp;sr                                                                            |
# | lx     | (lux)               | 1 m<sup>&minus;2</sup>&nbsp;cd&nbsp;sr                                                  |
# | m      | (metre)             | 1 m                                                                                     |
# | min    | (minute)            | 60 s                                                                                    |
# | mol    | (mole)              | 1 mol                                                                                   |
# | pc     | (parsec)            | 3.08567758065&times;10<sup>16</sup> m                                                   |
# | rad    | (radian)            | 1 rad                                                                                   |
# | s      | (second)            | 1 s                                                                                     |
# | sr     | (steradian)         | 1 sr                                                                                    |
# | t      | (tonne)             | 1000 kg                                                                                 |
#
# |         |                             |
# |:--------|-----------------------------|
# | Type    | Table                       |
# | ID      | reference-tab-physicalunits |
# | Caption | Physical SI Units           |
#
# &nbsp;
#
# | Unit       | Name                         | Value                                                                                                                                 |
# |:-----------|:-----------------------------|:--------------------------------------------------------------------------------------------------------------------------------------|
# | "          | (arcsec)                     | 4.8481368111&times;10<sup>&minus;6</sup>&nbsp;rad                                                                                     |
# | "\_2       | (square arcsec)              | 2.35044305391&times; 10<sup>&minus;11</sup>&nbsp;sr                                                                                   |
# | &rsquo;    | (arcmin)                     | 0.000290888208666 rad                                                                                                                 |
# | &rdquo;    | (arcsec)                     | 4.8481368111&times;10<sup>&minus;6</sup>&nbsp;rad                                                                                     |
# | &rdquo;\_2 | (square arcsec)              | 2.35044305391&times;10<sup>&minus;11</sup>&nbsp;sr                                                                                    |
# | &rsquo;\_2 | (square arcmin)              | 8.46159499408&times;10<sup>&minus;8</sup>&nbsp;sr                                                                                     |
# | :          | (hour)                       | 3600 s                                                                                                                                |
# | ::         | (minute)                     | 60 s                                                                                                                                  |
# | :::        | (second)                     | 1 s                                                                                                                                   |
# | Ah         | (ampere hour)                | 3600 s&nbsp;A                                                                                                                         |
# | Angstrom   | (angstrom)                   | 1e-10 m                                                                                                                               |
# | Btu        | (British thermal unit (Int)) | 1055.056 m<sup>2</sup>&nbsp;kg&nbsp;s<sup>&minus;2</sup>                                                                              |
# | CM         | (metric carat)               | 0.0002 kg                                                                                                                             |
# | Cal        | (large calorie (Int))        | 4186.8 m<sup>2</sup>&nbsp;kg&nbsp;s<sup>&minus;2</sup>                                                                                |
# | FU         | (flux unit)                  | 10<sup>&minus;26</sup>&nbsp;kg&nbsp;s<sup>&minus;2</sup>                                                                              |
# | G          | (gauss)                      | 0.0001 kg&nbsp;s<sup>&minus;2</sup>&nbsp;A<sup>&minus;1</sup>                                                                         |
# | Gal        | (gal)                        | 0.01 m&nbsp;s<sup>&minus;2</sup>                                                                                                      |
# | Gb         | (gilbert)                    | 0.795774715459 A                                                                                                                      |
# | Mx         | (maxwell)                    | 10<sup>&minus;8</sup>&nbsp;m<sup>2</sup>&nbsp;kg&nbsp;s<sup>&minus;2</sup>&nbsp;A<sup>&minus;1</sup>                                  |
# | Oe         | (oersted)                    | 79.5774715459 m<sup>&minus;1</sup>&nbsp;A                                                                                             |
# | R          | (mile)                       | 0.000258 kg<sup>&minus;1</sup>&nbsp;s&nbsp;A                                                                                          |
# | St         | (stokes)                     | 0.0001 m<sup>2</sup>&nbsp;s&minus;1                                                                                                   |
# | Torr       | (torr)                       | 133.322368421 m<sup>&minus;1</sup>&nbsp;kg&nbsp;s<sup>&minus;2</sup>                                                                  |
# | USfl_oz    | (fluid ounce (US))           | 2.95735295625&times;10<sup>&minus;5</sup>&nbsp;m<sup>3</sup>                                                                          |
# | USgal      | (gallon (US))                | 0.003785411784 m<sup>3</sup>                                                                                                          |
# | WU         | (WSRT flux unit)             | 5&times; 10<sup>&minus;29</sup>&nbsp;kg&nbsp;s<sup>&minus;2</sup>                                                                     |
# | abA        | (abampere)                   | 10 A                                                                                                                                  |
# | abC        | (abcoulomb)                  | 10 s&nbsp;A                                                                                                                           |
# | abF        | (abfarad)                    | 10<sup>9</sup>&nbsp;m<sup>&minus;2</sup>&nbsp;kg<sup>&minus;1</sup>&nbsp;s<sup>4</sup>&nbsp;A<sup>2</sup>                             |
# | abH        | (abhenry)                    | 10<sup>&minus;9</sup>&nbsp;m<sup>2</sup>&nbsp;kg&nbsp;s<sup>&minus;2</sup>&nbsp;A<sup>&minus;2</sup>                                  |
# | abOhm      | (abohm)                      | 10<sup>&minus;9</sup>&nbsp;m<sup>2</sup>&nbsp;kg&nbsp;s<sup>&minus;3</sup>&nbsp;A<sup>&minus;2</sup>                                  |
# | abV        | (abvolt)                     | 10<sup>&minus;8</sup>&nbsp;m<sup>2</sup>&nbsp;kg&nbsp;s<sup>&minus;3</sup>&nbsp;A<sup>&minus;1</sup>                                  |
# | ac         | (acre)                       | 4046.8564224 m<sup>2</sup>                                                                                                            |
# | arcmin_2   | (square arcmin)              | 8.46-2159499408&times;10<sup>&minus;8</sup>&nbsp;sr                                                                                   |
# | arcsec_2   | (square arcsec)              | 2.35044305391&times;10<sup>&minus;11</sup>&nbsp;sr                                                                                    |
# | ata        | (technical atmosphere)       | 98066.5 m<sup>&minus;1</sup>.kg.s<sup>&minus;2</sup>                                                                                  |
# | atm        | (standard atmosphere)        | 101325 m<sup>&minus;1</sup>.kg.s<sup>&minus;2</sup>                                                                                   |
# | bar        | (bar)                        | 100000 m<sup>&minus;1</sup>.kg.s<sup>&minus;2</sup>                                                                                   |
# | beam       | (undefined beam area)        | 1 \_                                                                                                                                  |
# | cal        | (calorie (Int))              | 4.1868 m<sup>2</sup>&nbsp;kg&nbsp;s<sup>&minus;2</sup>                                                                                |
# | count      | (count)                      | 1 \_                                                                                                                                  |
# | cwt        | (hundredweight)              | 50.80234544 kg                                                                                                                        |
# | deg_2      | (square degree)              | 0.000304617419787 sr                                                                                                                  |
# | dyn        | (dyne)                       | 10<sup>&minus;5</sup>&nbsp;m&nbsp;kg&nbsp;s<sup>&minus;2</sup>                                                                        |
# | eV         | (electron volt)              | 1.60217733&times;10<sup>&minus;19</sup>&nbsp;m<sup>2</sup>&nbsp;kg&nbsp;s<sup>&minus;2</sup>                                          |
# | erg        | (erg)                        | 10<sup>&minus;7</sup>&nbsp;m<sup>2</sup>&nbsp;kg&nbsp;s<sup>&minus;2</sup>                                                            |
# | fl_oz      | (fluid ounce (Imp))          | 2.84130488996&times;10<sup>&minus;5</sup>&nbsp;m<sup>3</sup>                                                                          |
# | ft         | (foot)                       | 0.3048 m                                                                                                                              |
# | fu         | (flux unit)                  | 10<sup>&minus;26</sup>&nbsp;kg&nbsp;s<sup>&minus;2</sup>                                                                              |
# | fur        | (furlong)                    | 201.168 m                                                                                                                             |
# | gal        | (gallon (Imp))               | 0.00454608782394 m<sup>3</sup>                                                                                                        |
# | ha         | (hectare)                    | 10000 m<sup>2</sup>                                                                                                                   |
# | hp         | (horsepower)                 | 745.7 m<sup>2</sup>&nbsp;kg&nbsp;s<sup>&minus;3</sup>                                                                                 |
# | in         | (inch)                       | 0.0254 m                                                                                                                              |
# | kn         | (knot (Imp))                 | 0.514773333333 m&nbsp;s<sup>&minus;1</sup>                                                                                            |
# | lambda     | (lambda)                     | 1 \_                                                                                                                                  |
# | lb         | (pound (avoirdupois))        | 0.45359237 kg                                                                                                                         |
# | ly         | (light year)                 | 9.46073047&times;10<sup>15</sup>&nbsp;m                                                                                               |
# | mHg        | (metre of mercury)           | 133322.387415 m<sup>&minus;1</sup>&nbsp;kg&nbsp;s<sup>&minus;2</sup>                                                                  |
# | mile       | (mile)                       | 1609.344 m                                                                                                                            |
# | n_mile     | (nautical mile (Imp))        | 1853.184 m                                                                                                                            |
# | oz         | (ounce (avoirdupois))        | 0.028349523125 kg                                                                                                                     |
# | pixel      | (pixel)                      | 1 \_                                                                                                                                  |
# | sb         | (stilb)                      | 10000 m<sup>&minus;2</sup>&nbsp;cd                                                                                                    |
# | sq_arcmin  | (square arcmin)              | 8.46159499408&times;10<sup>&minus;8</sup> sr                                                                                          |
# | sq_arcsec  | (square arcsec)              | 2.35044305391&times;10<sup>&minus;11</sup> sr                                                                                         |
# | sq_deg     | (square degree)              | 0.000304617419787 sr                                                                                                                  |
# | statA      | (statampere)                 | 3.33564095198&times;10<sup>&minus;10</sup>&nbsp;A                                                                                     |
# | statC      | (statcoulomb)                | 3.33564095198&times;10<sup>&minus;10</sup>&nbsp;s&nbsp;A                                                                              |
# | statF      | (statfarad)                  | 1.11188031733&times;10<sup>&minus;12</sup>&nbsp;m<sup>&minus;2</sup>&nbsp;kg<sup>&minus;1</sup>&nbsp;s<sup>4</sup>&nbsp;A<sup>2</sup> |
# | statH      | (stathenry)                  | 899377374000&nbsp;m<sup>2</sup>&nbsp;kg&nbsp;s<sup>&minus;2</sup>&nbsp;A<sup>&minus;2</sup>                                           |
# | statOhm    | (statohm)                    | 899377374000&nbsp;m<sup>2</sup>&nbsp;kg&nbsp;s<sup>&minus;3</sup>&nbsp;A<sup>&minus;2</sup>                                           |
# | statV      | (statvolt)                   | 299.792458 m<sup>2</sup>&nbsp;kg&nbsp;s<sup>&minus;3</sup>&nbsp;A<sup>&minus;1</sup>                                                  |
# | u          | (atomic mass unit)           | 1.661&times;10<sup>&minus;27</sup>&nbsp; kg                                                                                           |
# | yd         | (yard)                       | 0.9144 m                                                                                                                              |
# | yr         | (year)                       | 31557600 s                                                                                                                            |
#
# |         |                                     |
# |:--------|-------------------------------------|
# | Type    | Table                               |
# | ID      | reference-tab-customunits           |
# | Caption | Custom units available&nbsp;in CASA |
