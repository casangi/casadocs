# %% [markdown]
# # Examples
#
# task calstat examples
#
# To extract amplitude statistics from a 'G' caltable called
# ngc5921.demo.gcal with **calstat**:
#
# gstat=calstat('ngc5921.demo.gcal',axis='amp',datacolumn='CPARAM')
#
# The gstat
# variable will contain the following dictionary:
#
# {'CPARAM': {'max': 1.6031942367553711,
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; &nbsp; &nbsp; 'mean':
# 1.4448433067117419,
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; &nbsp; &nbsp; 'medabsdevmed':
# 0.0086394548416137695,
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; &nbsp; &nbsp; 'median':
# 1.5732669830322266,
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; &nbsp; &nbsp; 'min':
# 0.99916577339172363,
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; &nbsp; &nbsp; 'npts':
# 280.0,
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; &nbsp; &nbsp; 'quartile':
# 0.020265340805053711,
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; &nbsp; &nbsp; 'rms':
# 1.4650156497955322,
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; &nbsp; &nbsp; 'stddev':
# 0.24271160321065546,
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; &nbsp; &nbsp; 'sum':
# 404.55612587928772,
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; &nbsp; &nbsp; 'sumsq':
# 600.95579999685287,
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; &nbsp; &nbsp; 'var':
# 0.058908922333086665}}
#
# &nbsp;
#
# &nbsp;
