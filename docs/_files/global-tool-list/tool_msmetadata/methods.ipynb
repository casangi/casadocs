# %% [markdown]
# # Methods
#
# task applycal parameters
#
# &nbsp;
#
# constructor **msmetadata**
#
# Parameters : None
#
# function **almaspws**
#
# Get spectral window IDs based on ALMA-specific criteria. The inputs are
# or'ed together to form the returned list. If complement=True, then the
# complement of the selection is returned. The following algorithm is used
# to identify WVR spwectral windows: 1. check for water vapor radiometer
# (WVR) spectral windows using the spectral window name "WVR\#NOMINAL" and
# report these. 2. If no SPWs match that string, then the names are
# checked for "WVR" and are reported instead.
#
# Parameters
#
# chavg : undefined = false
#
# Get channel average spectral windows?
#
# fdm : undefined = false
#
# Get FDM spectral windows?
#
# sqld : undefined = false
#
# Get square law (i.e. total power) detector spectral windows?
#
# tdm : undefined = false
#
# Get TDM spectral windows?
#
# wvr : undefined = false
#
# Get WVR spectral windows?
#
# complement : undefined = false
#
# Return the complement of the selected set?
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get all square law detector spectral window IDs
# msmd.almaspws(sqld=True) \

# %% [markdown]
# ## get all spectral window IDs other than those
# associated with square law detectors msmd.almaspws(sqld=True,
# complement=True)
#
# function **antennadiameter**
#
# Get the diameter for the specified antenna. The antenna can be specified
# either by its zero-based ID from the ANTENNA table or by its name in
# that table. The returned dictionary is a valid quantity. If a negative
# integer is provided for the antenna, then all atenna diameters will be
# returned in a dictionary that has keys that are the antenna IDs and
# values that are dictionaries, each being a valid quantity representing
# the diameter for that antenna ID.
#
# Parameters
#
# antenna : any = -1
#
# Zero-based antenna in the ANTENNA table, or antenna name. A negative
# integer will cause all antenna diameters to be returned.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## Get the diameter of the antenna named "VB2"
# diameter = msmd.antennadiameter("VB2") msmd.done()
#
# function **antennaids**
#
# Get the zero-based antenna IDs for the specfied antenna names and the
# specified diameter range for the specified observation ID. An array of
# unique IDs in order of the specified names is returned. Note that if a
# specified name is listed mulitple times in the ANTENNA table, the
# largest ID is returned, unless the observation ID is specified to be
# non-negative, in which case, the returned IDs are filtered based on the
# specified observation ID. If no names and no diameter range is
# specified, all IDs are returned.
#
# Parameters
#
# name : any
#
# Antenna names (string or string array) for which to get the
# corresponding IDs. Note that \* matches any number of characters of all
# character classes.
#
# mindiameter : any = 0m
#
# Minimum antenna diameter, expressed as a quantity.
#
# maxdiameter : any = 1pc
#
# Maximum antenna diameter, expressed as a quantity.
#
# obsid : undefined = -1
#
# Observation ID. If negative, all observation IDs are considered.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the zero-based antenna IDs for the antenna
# named "VB2" antenna_id = msmd.antennaids("VB2")\[0\] \

# %% [markdown]
# ## get the
# zero-based antenna IDs for all antennas with diameters between 9m and
# 11m antenna_ids = msmd.antennaids(mindiameter="9m",
# maxdiameter=qa.quantity("11m")) msmd.done()
#
# function **antennanames**
#
# Get the name of the antenna for the specfied zero-based antenna ID. If
# antennaids is not specified, all antenna names are returned.
#
# Parameters
#
# antennaids : any = -1-1
#
# Zero-based antenna IDs (int or int array) for which to get the antenna
# names.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the name associated with antenna ID 31
# antenna_name = msmd.antennanames(31)\[0\] msmd.done()
#
# function **antennaoffset**
#
# Get the offset position of the specified antenna relative to the array
# reference position. Antenna may be specified as a zero-based integer
# (row number in the ANTENNA table) or a string representing a valid
# antenna name. The returned record contains the longitude, latitude, and
# elevation offsets as quantity records. The reported longitude and
# latitude offsets are measured along the surface of a sphere whose center
# is coincident with the center of the earth and whose surface contains
# the observatory reference position.
#
# Parameters
#
# which : any = 0
#
# Zero-based antenna in the ANTENNA table, or antenna name.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the offset of the (zero-based) 3rd antenna in
# the ANTENNA table antennna_offset = msmd.antennaoffset(3) \

# %% [markdown]
# ## get the
# offset of antenna DV02 antennna_offset = msmd.antennaoffset('DV02')
# msmd.done()
#
# function **antennaposition**
#
# Get the position of the specified antenna. The returned record
# represents a position measure, and can be used as such by the measures
# (me) tool.
#
# Parameters
#
# which : any = 0
#
# Zero-based antenna ID in the ANTENNA table or antenna name.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the position of the (zero-based) 3rd antenna
# in the ANTENNA table antennna_position = msmd.antennaposition(3) \

# %% [markdown]
# ## get
# the position of the antenna named DV07 antennna_position =
# msmd.antennaposition("DV07") msmd.done()
#
# function **antennastations**
#
# Get the station names of the specified antennas. If a specified antenna
# name is listed multiple times in the ANTENNA table, obsid is negative,
# and which is specified as an array of names, then the station associated
# with the largest ID for that antenna is returned. If obsid is
# nonnegative, returned stations are filtered based on that. If which is
# specified as a string (antenna name), then all the stations associated
# with that antenna are returned.
#
# Parameters
#
# which : any = -1
#
# Zero-based antenna ID(s) in the ANTENNA table or antenna name(s). Single
# numeric id less than zero retrieves all station names.
#
# obsid : undefined = -1
#
# Observation ID. If negative, all observation IDs are considered.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get all station names stations =
# msmd.antennastations(-1) \

# %% [markdown]
# ## get the stations of the antennas named DV07
# and DV01 stations = msmd.antennaposition(\["DV07", "DV01"\]) msmd.done()
#
# function **antennasforscan**
#
# Get an array of the unique antennaIDs for the specified scan,
# observation ID, and array ID.
#
# Parameters
#
# scan : undefined = -1
#
# Scan number for which to return the intents.
#
# obsid : undefined = -1
#
# Observation ID. If less than 0, all observation IDs are used.
#
# arrayid : undefined = -1
#
# Array ID. If less than 0, all array IDs are used.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the antennas associated with scan 4 (all
# observation IDs, all array IDs) antennas = msmd.antennasforscan(4)
# msmd.done()
#
# function **bandwidths**
#
# Get the bandwidths in Hz for the specified spectral windows. If spw less
# than zero, return bandwidths for all spectral windows.
#
# Parameters
#
# spw : any = -1
#
# Spectral window IDs, if integer less than zero, return bandwidths for
# all spectral windows.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get bandwdith for spectral window 2. baseband =
# msmd.bandwidth(2) msmd.done()
#
# function **baseband**
#
# Get the baseband for the specified spectral window.
#
# Parameters
#
# spw : undefined
#
# Spectral window ID.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get baseband for spectral window 2. baseband =
# msmd.baseband(2) msmd.done()
#
# function **baselines**
#
# Get a two dimensional boolean array representing baselines for data
# recorded in the MS. A value of True means there is at least one row in
# the MS main table for that baseline, False means no rows for that
# baseline. Autocorrelation "baseline" information is also present via the
# values along the diagonal.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the baseline matrix for this data set
# baselines = msmd.baselines() msmd.done()
#
# function **chanavgspws**
#
# Get an array of spectral window IDs used for channel averages. These are
# windows that do have 1 channel.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the spectral window IDs used for channel
# averages. chan_avg_spws = msmd.chanavgspws() msmd.done()
#
# function **chaneffbws**
#
# Get an array of channel effective bandwidths for the specified spectral
# window. The parameter asvel indicates if velocity widths (True) or
# frequency widths (False) should be returned. The unit parameter
# specifies the units that the returned values should have. If empty
# (default), "Hz" will be used if asvel=False, or "km/s" will be used if
# asvel=True.
#
# Parameters
#
# spw : undefined
#
# Spectral window ID.
#
# unit : undefined
#
# Desired unit of returned quantities. Empty means "Hz" if asvel=False,
# "km/s" if asvel=True.
#
# asvel : undefined = false
#
# Should return values be equivalent velocity widths?
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the channel effective bandwidths for spectral
# window 2, in m/s chan_ebw = msmd.chaneffbws(2, "m/s", True) msmd.done()
#
# function **chanfreqs**
#
# Get an array of channel frequencies for the specified spectral window.
#
# Parameters
#
# spw : undefined
#
# Spectral window ID.
#
# unit : undefined = Hz
#
# Convert frequencies to this unit.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the channel frequencies for spectral window 2.
# chan_freqs = msmd.chanfreqs(2) msmd.done()
#
# function **chanres**
#
# Get an array of channel resolutions for the specified spectral window.
# The parameter asvel indicates if velocity widths (True) or frequency
# widths (False) should be returned. The unit parameter specifies the
# units that the returned values should have. If empty (default), "Hz"
# will be used if asvel=False, or "km/s" will be used if asvel=True.
#
# Parameters
#
# spw : undefined
#
# Spectral window ID.
#
# unit : undefined
#
# Desired unit of returned quantities. Empty means "Hz" if asvel=False,
# "km/s" if asvel=True.
#
# asvel : undefined = false
#
# Should return values be equivalent velocity resolutions?
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the channel resolutions for spectral window 2,
# in m/s chan_res = msmd.chanres(2, "m/s", True) msmd.done()
#
# function **chanwidths**
#
# Get an array of channel widths for the specified spectral window.
#
# Parameters
#
# spw : undefined
#
# Spectral window ID.
#
# unit : undefined = Hz
#
# Convert frequencies to this unit.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the channel widths for spectral window 2.
# chan_freqs = msmd.chanwidths(2) msmd.done()
#
# function **close**
#
# This method will close the tool and reclaim system resources it has been
# using. Returns true if successful.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## do things with tool \

# %% [markdown]
# ## finish, close tool and free
# up resources. msmd.close()
#
# function **corrprodsforpol**
#
# Get the correlation products associated with the specified polarization
# ID.
#
# Parameters
#
# pol : undefined = -1
#
# Polarization ID. Must be nonnegative.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get correlation products for polarization ID 3
# corrprods = msmd.corrprodsforpol(3) msmd.done()
#
# function **corrtypesforpol**
#
# Get the correlation types associated with the specified polarization ID.
#
# Parameters
#
# pol : undefined = -1
#
# Polarization ID. Must be nonnegative.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get correlation types for polarization ID 3
# corrtypes = msmd.corrtypesforpol(3) msmd.done()
#
# function **datadescids**
#
# Get a list of data description IDs associated with the specified
# spectral window ID and/or polarization ID. Values of less than zero for
# either means all IDs should be used in the selection.
#
# Parameters
#
# spw : undefined = -1
#
# Spectral window ID. Less than zero implies any,
#
# pol : undefined = -1
#
# Polarization ID. Less than zero implies any.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get all data description IDs associated with spw
# 2. msmd.datadescids(spw=2) \

# %% [markdown]
# ## same as before but limit the IDs returned
# to those associated with \

# %% [markdown]
# ## polarization ID 3 msmd.datadescids(spw=2,
# pol=3) msmd.done()
#
# function **done**
#
# This method will close the tool and reclaim system resources it has been
# using. Returns true if successful.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## do things with tool \

# %% [markdown]
# ## finish, close tool and free
# up resources. msmd.done()
#
# function **effexposuretime**
#
# Get the effective exposure time (equivalent to what might be more
# commonly known as total integration time or total sample time) is
# calculated by summing over all rows in the main MS table, excluding
# autocorrelations or rows where FLAG\\\_ROW is false, thusly: sum\[over
# i\] (exposure\[i\]\*sum\[over j\](UFBW\[i, j\])/ncorrelations\[i\] )/
# nmaxbaselines where exposure\[i\] is the value of EXPOSURE for the ith
# row, the inner sum is performed over each correlation for that row, UFBW
# is the unflagged fractional bandwidth is determined by summing all the
# widths of the unflagged channels for that correlation and dividing by
# the total bandwidth of all spectral windows observed at the timestamp of
# row i, ncorrelations is the number of correlations determined by the
# number of rows in the FLAG matrix for MS row i, and nmaxbaselines is the
# maximum number of antenna pairs, nantennas\*(nantennas-1)/2, where
# nantennas is the number of antennas in the ANTENNA table. This method
# returns a quantity (a dictionary having a numerical value and a string
# unit).
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the effective exposure time. exposure_time =
# msmd.effexposuretime() msmd.done()
#
# function **exposuretime**
#
# Get the exposure time for the specified scan, spwid, polarization ID,
# array ID, and observation ID. This is the exposure time of the record
# with the lowest time stamp of the records associated with these
# parameters. Returns a quantity dictionary. If polid is not specified (or
# specified and negative) and there is only one polarization ID in for the
# specified combination of scan, spwid, obsID, and arrayID, then that
# polarization ID is used. If there are multiple polarization IDs for the
# combination of other parameters, a list of these is logged and an empty
# dictionary is returned.
#
# Parameters
#
# scan : undefined = 0
#
# Scan number.
#
# spwid : undefined = 0
#
# Spectral window ID.
#
# polid : undefined = -1
#
# Polarization ID.
#
# obsid : undefined = 0
#
# Observation ID.
#
# arrayid : undefined = 0
#
# Array ID.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the exposure time for scan 1, spwid 2, and
# polid 3 \

# %% [markdown]
# ## for obsid=0 and arrayid=0 integration_time =
# msmd.exposuretime(scan=1, spwid=2, polid=3) msmd.done()
#
# function **fdmspws**
#
# Get an array of spectral window IDs used for FDM. These are windows that
# do not have 64, 128, or 256 channels.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the spectral window IDs used for FDM. fdm_spws
# = msmd.fdmspws() msmd.done()
#
# function **fieldnames**
#
# Get an array of field names as they appear in the FIELD table.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get list of field names in the ms fieldnames =
# msmd.fieldnames() msmd.done()
#
# function **fieldsforintent**
#
# Get an array of the unique fields for the specified intent. Note that \*
# matches any number of characters of all character classes.
#
# Parameters
#
# intent : undefined
#
# Intent (case sensitive) for which to return the fields.
#
# asnames : undefined = false
#
# If true, return the field names. If false, return the zero-based field
# IDs.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the field names for intent "observe target"
# field_names = msmd.fieldsforintent("observe target", True, regex=False)
# \

# %% [markdown]
# ## get the field IDs for intent "observe target" field_IDs =
# msmd.fieldsforintent("observe target", False, regex=False) \

# %% [markdown]
# ## get all
# field IDs for all intents which contain 'WVR' field_IDs =
# msmd.fieldsforIntent("\*WVR\*") msmd.done()
#
# function **fieldsforname**
#
# Get an array of the unique, zero-based field IDs for the specified field
# name. If the field name is the empty string (the default), a list of all
# unique field IDs in the main table of the MS will be returned.
#
# Parameters
#
# name : undefined
#
# Field name (case sensitive) for which to return the fields.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the field IDs for field name "Enceladus"
# fields = msmd.fieldsforname("Enceladus") msmd.done()
#
# function **fieldsforscan**
#
# Get an array of the unique fields for the specified scan number,
# observation ID, and array ID.
#
# Parameters
#
# scan : undefined = -1
#
# Scan number for which to return the fields.
#
# asnames : undefined = false
#
# If true, return the field names. If false, return the zero-based field
# IDs.
#
# obsid : undefined = -1
#
# Observation ID. A negative value means use all observation IDs.
#
# arrayid : undefined = -1
#
# Array ID. A negative value means use all array IDs.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the field names for scan number 5 (for all
# array IDs and all observation IDs). field_names = msmd.fieldsforscan(5,
# True) \

# %% [markdown]
# ## get the field IDs for scan number 5 (for all array IDs and all
# observation IDs) field_IDs = msmd.fieldsforscan(5, False) msmd.done()
#
# function **fieldsforscans**
#
# Get an array or dictionary of the unique fields for the specified scan
# numbers, observation ID, and array ID. If asnames=True, the values
# returned will be the field names, if False, they will be field IDs. If
# asmap=True, the structure returned will be a dictionary which maps scan
# number (as a string) to fields. In this case, both obsid and arrayid
# must be nonnegative. If asmap=False, a single array of fields is
# returned that matches the query. In this case, if obsid and/or arrayid
# are negative, then it indicates that all fields matching any obsid
# and/or arrayid should be returned. An empty array specified for scans
# means that all scans for the selected obsid and arrayid should be
# included.
#
# Parameters
#
# scans : undefined
#
# Scan numbers for which to return the fields.
#
# asnames : undefined = false
#
# If true, return the field names. If false, return the zero-based field
# IDs.
#
# obsid : undefined = -1
#
# Observation ID. A negative value means use all observation IDs.
#
# arrayid : undefined = -1
#
# Array ID. A negative value means use all array IDs.
#
# asmap : undefined = false
#
# Return a dictionary mapping scan numbers to fields?
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the field names for scan numbers 5 and 10 (all
# obsids, all arrayids) field_names = msmd.fieldsforscan(\[5, 10\], True)
# \

# %% [markdown]
# ## get the field IDs for scan numbers 5 and 10 (all obsids, all
# arrayids) field_IDs = msmd.fieldsforscan(\[5, 10\], False) \

# %% [markdown]
# ## get
# mapping of scans to fields for arrayid=2 and obsid=4 scans_to_fields =
# msmd.fieldsforscan(obsid=4, arrayid=2, asmap=True) msmd.done()
#
# function **fieldsforsource**
#
# Get an array of the unique fields for the specified source.
#
# Parameters
#
# source : undefined = -1
#
# Zero-based source ID for which to return the fields.
#
# asnames : undefined = false
#
# If true, return the field names. If false, return the zero-based field
# IDs.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the field names for source ID 1 field_names =
# msmd.fieldsforsource(1, True) \

# %% [markdown]
# ## get the field IDs for source ID 1
# field_IDs = msmd.fieldsforsource(1, False) msmd.done()
#
# function **fieldsforsources**
#
# Get a map of source IDs to fields. The keys (source IDs) will be
# strings.
#
# Parameters
#
# asnames : undefined = false
#
# If true, return the field names. If false, return the zero-based field
# IDs.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the source to field name map sources_to_fields
# = msmd.fieldsforsources(True) \

# %% [markdown]
# ## access the field names for source 1
# field = sources_to_fields\["1"\] msmd.done()
#
# function **fieldsforspw**
#
# Get an array of the unique fields for the specified spectral window.
#
# Parameters
#
# spw : undefined = -1
#
# Zero-based spectral window ID for which to return the fields.
#
# asnames : undefined = false
#
# If true, return the field names. If false, return the zero-based field
# IDs.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the field names for spectral window 1
# field_names = msmd.fieldsforspw(1, True) \

# %% [markdown]
# ## get the field IDs for
# spectral window 1 field_IDs = msmd.fieldsforspw(1, False) msmd.done()
#
# function **fieldsfortimes**
#
# Get an array of the unique, zero-based, fieldIDs for the specified time
# range (time-tol to time+tol).
#
# Parameters
#
# time : undefined = -1
#
# Time at center of time range.
#
# tol : undefined = 0
#
# Time on either side of center for specifying range.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the field IDs associated with the specified
# time range fields = msmd.fieldsfortimes(4.8428293714e+09, 20)
# msmd.done()
#
# function **intents**
#
# Get an array of the unique intents associated with the MS.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the intents associated with the MS intents =
# msmd.intents() msmd.done()
#
# function **intentsforfield**
#
# Get an array of the unique intents for the specified field.
#
# Parameters
#
# field : any = -1
#
# Field ID or name for which to return the intents.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the intents associated with field 4 intents =
# msmd.intentsforfield(4) \

# %% [markdown]
# ## get intents for field "MOS" intents2 =
# msmd.intentsforfield("MOS") msmd.done()
#
# function **intentsforscan**
#
# Get an array of the unique intents for the specified scan, observation
# ID, and array ID.
#
# Parameters
#
# scan : undefined = -1
#
# Scan number for which to return the intents.
#
# obsid : undefined = -1
#
# Observation ID. A negative value means use all observation IDs.
#
# arrayid : undefined = -1
#
# Array ID. A negative value means use all array IDs.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the intents associated with scan 4 (all
# obsids, all arrayids) intents = msmd.intentsforscan(4) msmd.done()
#
# function **intentsforspw**
#
# Get an array of the unique intents for the specified spectral window ID.
#
# Parameters
#
# spw : undefined = -1
#
# Spectral window ID (\\\>=0) for which to return the intents.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the intents associated with spectral window ID
# 3 intents = msmd.intentsforspw(3) msmd.done()
#
# function **meanfreq**
#
# Get the mean frequency for the specified spectral window.
#
# Parameters
#
# spw : undefined
#
# Spectral window ID.
#
# unit : undefined = Hz
#
# Convert frequencies to this unit.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the mean frequency for spectral window 2.
# mean_freq = msmd.meanfreq(2) msmd.done()
#
# function **name**
#
# Get the name of the attached MS.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get its name myname = msmd.name() msmd.done()
#
# function **namesforfields**
#
# Get the name of the specified field.
#
# Parameters
#
# fieldids : any
#
# Zero-based field IDs for which to get the names (integer or interger
# array). Unspecified will return all field names.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the name for field 8 and 2. field_names =
# msmd.namesforfields(\[8, 2\]) \

# %% [markdown]
# ## get all field names all_field_nams =
# namesforfields() msmd.done()
#
# function **namesforspws**
#
# Get the name of the specified spw(s).
#
# Parameters
#
# spwids : any
#
# Zero-based spw ID(s) for which to get the names (integer or interger
# array). Unspecified will return all spw names.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the name for spws 8 and 2. spw_names =
# msmd.namesforspws(\[8, 2\]) \

# %% [markdown]
# ## get all spw names all_spw_names =
# msmd.namesforspws() msmd.done()
#
# function **nantennas**
#
# Get the number of antennas associated with the MS.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") number_of_antennas = msmd.nantennas() msmd.done()
#
# function **narrays**
#
# Get the number of arrays associated with the MS from the ARRAY table.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") number_of_array_ids = msmd.narrays() msmd.done()
#
# function **nbaselines**
#
# Get the number of unique baselines (antenna pairs) represented in the
# main MS table. This can, in theory, be less than n\*(n-1)/2 (n being the
# number of antennas in the ANTENNA table), if data for certain baselines
# are not included in the main MS table. Autocorrelation "baselines" are
# included in this count if ac=True.
#
# Parameters
#
# ac : undefined = false
#
# Include auto-correlation "baselines"?
#
# Example
#
# msmd.open("my.ms") number_of_baselines = msmd.nbaselines()
# number_of_baselines_including_ac = msmd.nbaselines(True) msmd.done()
#
# function **nchan**
#
# Get the number of channels associated with the specified spectral
# window.
#
# Parameters
#
# spw : undefined
#
# Zero-based spw ID for which to get the number of channels.
#
# Example
#
# msmd.open("my.ms") nchan = msmd.nchan(3) msmd.done()
#
# function **ncorrforpol**
#
# Get the number of correlations for the specified polarization ID. If the
# specified polarization ID is negative, an array of numbers of
# correlations is returned. The indices of that array represent
# polarization IDs.
#
# Parameters
#
# polid : undefined = -1
#
# Zero-based polarization ID. A negative number will cause all the numbers
# of correlations to be returned.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the number of correlations associated with
# polarization ID 4 polid = msmd.ncorrforpol(4) \

# %% [markdown]
# ## get the array of
# numbers of correlations from the POLARIZATION table polids =
# msmd.ncorrforpol(-1) msmd.done()
#
# function **nfields**
#
# Get the number of fields associated with the MS.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") number_of_fields = msmd.nfields() msmd.done()
#
# function **nobservations**
#
# Get the number of observations associated with the MS from the
# OBSERVATIONS table.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") number_of_obs_ids = msmd.nobservations() msmd.done()
#
# function **nspw**
#
# This method will return the number of spectral windows in the associated
# MS.
#
# Parameters
#
# includewvr : undefined = true
#
# Include wvr spectral windows? If false, exclude wvr windows from count.
#
# Example
#
# msmd.open("my.ms") number_of_spectral_windows = msmd.nspw() msmd.done()
#
# function **nstates**
#
# This method will return the number of states (number of rows in the
# STATES table) in the associated MS.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") number_of_states = msmd.nstates() msmd.done()
#
# function **nscans**
#
# Get the number of scans associated with the MS.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") number_of_scans = msmd.nscans() msmd.done()
#
# function **nsources**
#
# Get the number of unique values from the SOURCE_ID column in the SOURCE
# table. The number of rows in the SOURCE table may be greater than this
# value.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") number_of_unique_source_ids = msmd.nsources()
# msmd.done()
#
# function **nrows**
#
# Get the number of visibilities (from the main table) associated with the
# MS.
#
# Parameters
#
# autoc : undefined = true
#
# Include autocorrelation data? If False, only cross correlation rows will
# be summed.
#
# flagged : undefined = true
#
# Include flagged data? If False, only unflagged or patially flagged rows
# will be summed.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the total number of rows nrows = msmd.nrows()
# \

# %% [markdown]
# ## got the number of cross correlation rows ncross =
# msmd.nrows(auto=False) \

# %% [markdown]
# ## get the number of unflagged rows ngood =
# msmd.nrows(flagged=False) \

# %% [markdown]
# ## get the number of unflagged cross
# correlation rows ncrossunflagged = msmd.nrows(auto=False, flagged=False)
# msmd.done()
#
# function **observers**
#
# Get an array of observers as they are listed in the OBSERVATIONS table.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the observers observers = msmd.observers()
# msmd.done()
#
# function **observatorynames**
#
# Get an array of MS telescope (observatory) names as they are listed in
# the OBSERVATIONS table.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the telescope names telescope_names =
# msmd.telescopenames() msmd.done()
#
# function **observatoryposition**
#
# Get the position of the specified telescope.
#
# Parameters
#
# which : undefined = 0
#
# Zero-based telescope position in the OBSERVATIONS table (see
# msmd.telescopenames()).
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the position of the 0th telescope
# telescope_position = msmd.telescopeposition(0) msmd.done()
#
# function **open**
#
# Attach this tool to the specified MS. This method runs a few basic MS
# validation tests, and if any of these fail (which indicates that the MS
# is invalid), an error occurs and the tool is not attached to the MS.
# Note that it is ultimately the user's responsibility to ensure that the
# MS is valid. Running the methods of this tool on an invalid MS may
# result in incorrect results or even a crash of CASA. Such invalidities
# include any MS subtable not having appropriate information (eg, an
# OBSERVATION subtable not having enough rows to account for all the
# OBSERVATION_IDs in the main table).
#
# Parameters
#
# msfile : undefined
#
# Name of the existing measurement set
#
# maxcache : undefined = 50
#
# Maximum cache size, in megabytes, to use.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## do stuff and close it msmd.done()
#
# function **phasecenter**
#
# Get a direction measures for the phasecenter of the field id and time
# specified
#
# Parameters
#
# fieldid : undefined = 0
#
# Zero-based field ID for which to get the phasecenter; default fieldid=0
#
# epoch : undefined
#
# Optional time, expressed as a measures epoch dictionary, if field id has
# a polynomial in time phasecenter or an ephemerides table attached to the
# ID. Default value means evaluate at the origin TIME in the FIELD table
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get phasecenter for field ID 1 mydir =
# msmd.phasecenter(1); \

# %% [markdown]
# ## if the phasecenter is a polynomial or has an
# ephemerides attached to \

# %% [markdown]
# ## it a time is needed to get the phase
# direction ep=me.epoch('utc', '2015/03/15/15:30:55')
# mydir2=msmd.phasecenter(2, ep) msmd.done()
#
# function **pointingdirection**
#
# Get the pointing direction for antennas at the specified row number in
# the main MS table. Returns a record containing the time, antenna IDs and
# corresponding pointing directions.
#
# Parameters
#
# rownum : undefined = 0
#
# Row number in the main MS table.
#
# interpolate : undefined = false
#
# Interpolate pointings in case the interval in the main table is shorter
# than that in the pointing table (often the case in fast-scanning in
# single dish observaitions)
#
# initialrow : undefined = 0
#
# Initial guess of row index in pointing table to start search.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the pointing directions for row ID 500 dirs =
# msmd.pointingdirection(500) msmd.done()
#
# function **polidfordatadesc**
#
# Get the polarization ID associated with the specified data description
# ID. If the specified data description ID is negative, an array of
# polarization IDs is returned. The indices of that array represent data
# description IDs.
#
# Parameters
#
# ddid : undefined = -1
#
# Zero-based data description ID. A negative number will cause all the
# polarization IDs to be returned.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the polarization ID associated with data
# description ID 3 polid = msmd.polidfordatadesc(3) \

# %% [markdown]
# ## get the array of
# polarization IDs in the order they appear in the DATA_DESCRIPTION table
# polids = msmd.polidfordatadesc(-1) msmd.done()
#
# function **projects**
#
# Get an array of projects as they are listed in the OBSERVATIONS table.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the projects projects = msmd.projects()
# msmd.done()
#
# function **propermotions**
#
# Get the values of the DIRECTION column from the SOURCE table. Returns a
# dictionary in which the keys are the associated zero-based row numbers,
# represented as strings, in the SOURCE table. The associated values are
# two element dictionaries, with keys "longitude" and "latitude",
# containing the longitudinal and latidinal components of the proper
# motion, which are valid quantity dictionaries.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get PROPER_MOTION column values from the SOURCE
# table mu = msmd.propermotions() msmd.done() \

# %% [markdown]
# ## the direction associated
# with zero-based row number 10 mu10 = mu\["10"\]
#
# function **refdir**
#
# Get a direction measure for the reference direction of the field and
# time specified
#
# Parameters
#
# field : any = 0
#
# Zero-based field ID or field name for which to get the reference
# direction; default field=0
#
# epoch : undefined
#
# Optional time, expressed as a measures epoch dictionary, if associated
# field has a polynomial in time reference direction or an ephemerides
# table attached it. Default value means evaluate at the origin TIME in
# the FIELD table
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get reference direction for field ID 1 mydir =
# msmd.refdir(1); \

# %% [markdown]
# ## if the reference direction is a polynomial or has an
# ephemerides attached to \

# %% [markdown]
# ## it a time is needed to get the reference
# direction ep=me.epoch('utc', '2015/03/15/15:30:55')
# mydir2=msmd.phasecenter(2, ep) msmd.done()
#
# function **reffreq**
#
# Get the reference frequency of the specified spectral window. The
# returned frequency is in the form of a valid measures dictionary.
#
# Parameters
#
# spw : undefined = -1
#
# Zero-based spectral window ID.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the reference frequency for spw ID 20 reffreq
# = msmd.reffreq(20) msmd.done()
#
# function **restfreqs**
#
# Get the rest frequencies from the SOURCE table for the specified source
# and spectral window. The return value will be a dictionary of frequency
# measures if the rest frequencies are defined for the specified inputs,
# or False if they do not.
#
# Parameters
#
# sourceid : undefined = 0
#
# Zero-based source ID (from the SOURCE::SOURCE_ID column).
#
# spw : undefined = 0
#
# Zero-based spectral window ID.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the rest frequencies for source ID 2 and spw
# ID 20 reffreq = msmd.restfreqs(2, 20) msmd.done()
#
# function **scannumbers**
#
# This method will return an array of unique scan numbers in the
# associated MS for the specified observation ID and array ID.
#
# Parameters
#
# obsid : undefined = -1
#
# Observation ID. A negative value indicates all observation IDs should be
# used.
#
# arrayid : undefined = -1
#
# Array ID. A negative value indicates all array IDs should be used.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## scan numbers for all obsids and all arrayids
# scan_numbers = msmd.scannumbers() msmd.done()
#
# function **scansforfield**
#
# Get an array of the unique scan numbers associated with the specified
# field, observation ID, and array ID.
#
# Parameters
#
# field : any
#
# Field ID or field name (case sensitive) for which to return the scan
# numbers.
#
# obsid : undefined = -1
#
# Observation ID. A negative value indicates all observation IDs should be
# used.
#
# arrayid : undefined = -1
#
# Array ID. A negative value indicates all array IDs should be used.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the scan numbers associated with field "planet
# Z" (all obsids, all arrayids) scan_numbers = msmd.scansforfield("planet
# Z") \

# %% [markdown]
# ## get the scan numbers associated with field ID 5 (all obsids, all
# arrayids) scan_numbers = msmd.scansforfield(5) msmd.done()
#
# function **scansforfields**
#
# Get a dictionary of which maps field ID to scan numbers for the
# specified observation ID and array ID. The keys (field IDs) will be
# strings. obsid and arrayid must both be non-negative.
#
# Parameters
#
# obsid : undefined = 0
#
# Observation ID. Must be non-negative.
#
# arrayid : undefined = 0
#
# Array ID. Must be non-negative.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the field - scan map for arrayID 1 and obsID 2
# field_to_scans = msmd.scansforfields(arrayid=1, obsid=2) \

# %% [markdown]
# ## access the
# scans associated with field ID 2 field_to_scans2 = field_to_scans\["2"\]
# msmd.done()
#
# function **scansforintent**
#
# Get an array of the unique scan numbers associated with the specified
# intent, observation ID, and arrayID. The "\*" character matches any
# number of characters from all character classes.
#
# Parameters
#
# intent : undefined
#
# Intent (case-sensitive) for which to return the scan numbers.
#
# obsid : undefined = -1
#
# Observation ID. A negative value indicates all observation IDs should be
# used.
#
# arrayid : undefined = -1
#
# Array ID. A negative value indicates all array IDs should be used.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the scan numbers associated with intent
# "detect planet X" (all obsids, all arrayids) scan_numbers =
# msmd.scansforintent("detect planet X", regex=False) \

# %% [markdown]
# ## got all the scan
# numbers associated with all intents which contain 'WVR' (all obsids, all
# arrayids) scan_numbers = msmd.scansforintent("\*WVR\*") msmd.done()
#
# function **scansforspw**
#
# Get an array of the unique scan numbers associated with the specified
# zero-based spectral window ID, observation ID, and array ID.
#
# Parameters
#
# spw : undefined = -1
#
# Zero-based spectral window ID for which to return the scan numbers.
#
# obsid : undefined = -1
#
# Observation ID. A negative value indicates all observation IDs should be
# used.
#
# arrayid : undefined = -1
#
# Array ID. A negative value indicates all array IDs should be used.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the scan numbers associated with spectral
# window ID 14, all obsids, all arrayids scan_numbers =
# msmd.scansforspw(14) msmd.done()
#
# function **scansforspws**
#
# Get a dictionary of which maps spw ID to scan numbers for the specified
# observation ID and array ID. The keys (spectral window IDs) will be
# strings. obsid and arrayid must both be non-negative.
#
# Parameters
#
# obsid : undefined = 0
#
# Observation ID. Must be non-negative.
#
# arrayid : undefined = 0
#
# Array ID. Must be non-negative.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the spw - scan map for arrayID 1 and obsID 2
# spw_to_scans = msmd.scansforspws(arrayid=1, obsid=2) \

# %% [markdown]
# ## access the scans
# associated with spw ID 2 spw_to_scans2 = spw_to_scans\["2"\] msmd.done()
#
# function **scansforstate**
#
# Get an array of the unique scan numbers for the specified state,
# observation ID, and array ID.
#
# Parameters
#
# state : undefined = -1
#
# ID of state for which to return the scan numbers.
#
# obsid : undefined = -1
#
# Observation ID. A negative value indicates all observation IDs should be
# used.
#
# arrayid : undefined = -1
#
# Array ID. A negative value indicates all array IDs should be used.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the scan numbers associated with state 2, all
# obsids, all arrayids scans = msmd.scansforstate(2) msmd.done()
#
# function **scansfortimes**
#
# Get an array of the unique scan numbers for the specified time range
# (time-tol to time+tol), observation ID, and array ID.
#
# Parameters
#
# time : undefined = -1
#
# Time at center of time range.
#
# tol : undefined = 0
#
# Time difference on either side of center for specifying range.
#
# obsid : undefined = -1
#
# Observation ID. A negative value indicates all observation IDs should be
# used.
#
# arrayid : undefined = -1
#
# Array ID. A negative value indicates all array IDs should be used.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the scan numbers associated with the specified
# time range (all obsids, all array ids) scans =
# msmd.scansfortimes(4.84282937e+09, 20) msmd.done()
#
# function **schedule**
#
# Get the schedule information for the specified observation ID.
#
# Parameters
#
# obsid : undefined = -1
#
# Observation ID.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the schdule information for observation ID = 2
# schedule = msmd.schedule()\[2\] msmd.done()
#
# function **sideband**
#
# Get the sideband for the specified spectral window.
#
# Parameters
#
# spw : undefined
#
# Spectral window ID.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get sideband for spectral window 2. sideband =
# msmd.sideband(2) msmd.done()
#
# function **sourcedirs**
#
# Get the values of the DIRECTION column from the SOURCE table. Returns a
# dictionary in which the keys are the associated row numbers, represented
# as strings, in the SOURCE table. Each value in the returned dictionary
# is a valid direction measure.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get DIRECTION column values from the SOURCE table
# sourcedirs = msmd.sourcedirs() msmd.done() \

# %% [markdown]
# ## the direction associated
# with zero-based row number 10 dir10 = sourcedirs\["10"\] \

# %% [markdown]
# ## convert it
# to B1950, using the measure interface dir10_B1950 = me.convert(dir10,
# "B1950")
#
# function **sourcetimes**
#
# Get the values of the TIME column from the SOURCE table. Returns a
# dictionary in which the keys are the associated row numbers, represented
# as strings, in the SOURCE table. Each value in the returned dictionary
# is a valid time quantity.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get TIME column values from the SOURCE table
# sourcetimes = msmd.sourcetimes() msmd.done() \

# %% [markdown]
# ## the time associated with
# zero-based row number 10 time10 = sourcetimes\["10"\]
#
# function **sourceidforfield**
#
# Get the source ID from the field table for the specified field ID.
#
# Parameters
#
# field : undefined = -1
#
# Zero-based field ID for which to return the source ID from the field
# table.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get source ID associated with field ID 2 sourceid
# = msmd.sourceidforfield(2) msmd.done()
#
# function **sourceidsfromsourcetable**
#
# Get the values of the SOURCE_ID column from the SOURCE table. It is
# unfortunate that the SOURCE table has a column named SOURCE_ID, because
# implicitly the "ID" of a row in an MS subtable is generally meant to
# reflect a row number in that table, but that is not the case for the
# SOURCE table.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get SOURCE_ID column values from the SOURCE table
# sourceids = msmd.sourceidsfromsourcetable() msmd.done()
#
# function **sourcenames**
#
# Get the values of the SOURCE_NAME column from the SOURCE table.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get SOURCE_NAME column values from the SOURCE
# table sourcenames = msmd.sourcenames() msmd.done()
#
# function **spwsforbaseband**
#
# Get the spectral windows associated with the specified baseband or
# dictionary that maps baseband to spectral windows.
#
# Parameters
#
# baseband : undefined = -1
#
# Baseband number. If \\\<0, return a dictionary mapping basebands to
# spws.
#
# sqldmode : undefined = include
#
# If "include", include SQLD windows, if "exclude", exclude SQLD windows,
# if "only", include only SQLD windows. Case insenstive, inimum match
# honored.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the spectral window IDs associated with all
# the basebands in this dataset basebandtospwdict =
# msmd.spwsforbasebands() \

# %% [markdown]
# ## get an array of spws associated with baseband
# 2. spwsforbb2 = msmd.spwsforbasebands(2) msmd.done()
#
# function **spwfordatadesc**
#
# Get the spectral window ID associated with the specified data
# description ID. If the specified data description ID is negative, an
# array of spectral window IDs is returned. The indices of that array
# represent data description IDs.
#
# Parameters
#
# ddid : undefined = -1
#
# Zero-based data description ID. A negative number will cause all the
# spectral window IDs to be returned.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the spectral window ID associated with data
# description ID 3 spw = msmd.spwfordatadesc(3) \

# %% [markdown]
# ## get the array of
# spectral window IDs in the order they appear in the DATA_DESCRIPTION
# table spws = msmd.spwfordatadesc(-1) msmd.done()
#
# function **spwsforfield**
#
# Get an array of the unique spectral window IDs for the specified field.
#
# Parameters
#
# field : any
#
# Field (case sensitive string or zero-based integer ID) for which to
# return the spectral window IDs.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the spectral window IDs associated with field
# "Fomalhaut" spws = msmd.spwsforfield("Fomalhaut") \

# %% [markdown]
# ## get spectral window
# IDs associated with field ID 2 spws = msmd.spwsforfield(2) msmd.done()
#
# function **spwsforfields**
#
# Get a dictionary which maps field IDs to spectral window IDs. The field
# IDs are keys in the returned dictionary. To access a particular element,
# one must ensure the key is a string.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the map of field IDs to spw IDs
# field_to_spw_map = msmd.spwsforfields() spws_for_field_5 =
# field_to_spw_map\[str(5)\] msmd.done()
#
# function **spwsforintent**
#
# Get an array of the unique spectral window IDs for the specified intent.
# The "\*" character matches any number of characters from all character
# classes.
#
# Parameters
#
# intent : undefined
#
# Intent (case sensitive) for which to return the spectral window IDs.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the spectral window IDs associated with "MY
# COOL INTENT" spws = msmd.spwsforintent("MY COOL INTENT") \

# %% [markdown]
# ## got all the
# spw IDs associated with all intents which contain 'WVR' scan_numbers =
# msmd.spwsforintent("\*WVR\*") msmd.done() msmd.done()
#
# function **spwsfornames**
#
# Get the IDs of the specified spw(s). Returns a dictionary where the keys
# are the requested spectral window names that are present in the data set
# and the values are arrays of the spectral window IDs corresponding to
# the name. If a specified name is not present, a warning message is
# logged and that name is not included in the returned dictionary.
# Specifying no names results in a dictionary containing the name to spw
# ID mapping for the entire data set.
#
# Parameters
#
# spwids : any
#
# Names of the spws for which IDs are needed (string or string array).
# Unspecified will return all spw names.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the IDs for spws named "CO" and "HCN" spw_ids
# = msmd.spwsfornames(\["CO", "HCN"\]) \

# %% [markdown]
# ## get the complete spw name to ID
# map spw_names_to_ids = msmd.spwsfornames() msmd.done()
#
# function **spwsforscan**
#
# Get an array of the unique spectral window IDs for the specified scan
# number, observation ID, and array ID.
#
# Parameters
#
# scan : undefined = -1
#
# Scan number for which to return the spectral window IDs.
#
# obsid : undefined = -1
#
# Observation ID. A negative value means that all observation IDs should
# be used.
#
# arrayid : undefined = -1
#
# Array ID. A negative value means that all array IDs should be used.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the spectral window IDs associated with scan
# number 20, all obsids, all arrayids. spws = msmd.spwsforscan(20)
# msmd.done()
#
# function **spwsforscans**
#
# Get a dictionary of which maps scan number to spectral windows for the
# specified observation ID and array ID. The keys (scan numbers) will be
# strings. obsid and arrayid must both be non-negative.
#
# Parameters
#
# obsid : undefined = 0
#
# Observation ID. Must be non-negative.
#
# arrayid : undefined = 0
#
# Array ID. Must be non-negative.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the scan - spw map for arrayID 1 and obsID 2
# scan_to_spws = msmd.spwsforscans(arrayid=1, obsid=2) \

# %% [markdown]
# ## access the spws
# associated with scan 2 spws_for_scan2 = scan_to_spws\["2"\] msmd.done()
#
# function **statesforscan**
#
# Get an array of the unique state IDs for the specified scan number,
# observation ID, and array ID.
#
# Parameters
#
# scan : undefined = -1
#
# Scan number for which to return the state IDs.
#
# obsid : undefined = -1
#
# Observation ID. A negative value means that all observation IDs should
# be used.
#
# arrayid : undefined = -1
#
# Array ID. A negative value means that all array IDs should be used.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the state IDs associated with scan number 251,
# all obsids, all arrayids states = msmd.statesforscan(251) msmd.done()
#
# function **statesforscans**
#
# Get a dictionary which maps scan numbers to state IDs for the specified
# array and observation IDs. The returned dictionary will have scan
# numbers, as strings, as keys.
#
# Parameters
#
# obsid : undefined = 0
#
# Observation ID, must be nonnegative.
#
# arrayid : undefined = 0
#
# Array ID, must be nonnegative.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the map of scan numbers to state IDs for
# arrayID=1, obsID=2 scans_to_states = msmd.statesforscans(obsID=2,
# arrayID=1) states_for_scan_5 = scans_to_states\[str(5)\] msmd.done()
#
# function **summary**
#
# Get dictionary summarizing the MS.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the summary summary = msmd.summary()
# msmd.done()
#
# function **tdmspws**
#
# Get an array of spectral window IDs used for TDM. These are windows that
# have 64, 128, or 256 channels.
#
# Parameters : None
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the spectral window IDs used for TDM. tdm_spws
# = msmd.tdmspws() msmd.done()
#
# function **timerangeforobs**
#
# Get the time range for the specified observation ID. The return value is
# a dictionary containing keys "begin" and "end". Each of the associated
# value are dictionaries representing epochs which are valid measure
# records. The values are taken directly from the OBSERVATION subtable; no
# half-intervals are added or subtracted.
#
# Parameters
#
# obsid : undefined = -1
#
# Zero-based observation ID for which to get the time range.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the time range associated with observation ID
# 3 timerange = msmd.timerangeforobs(3) msmd.done()
#
# function **timesforfield**
#
# Get an array of the unique times for the specified field.
#
# Parameters
#
# field : undefined = -1
#
# Zero-based field ID for which to return the times.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the times associated with field 3 times =
# msmd.timesforfields(3) msmd.done()
#
# function **timesforintent**
#
# Get an array of the unique times for the specified intent.
#
# Parameters
#
# intent : undefined
#
# Intent for which to return the times.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the times associated with intent "myintent"
# times = msmd.timesforintent("myintent") msmd.done()
#
# function **timesforscan**
#
# Get the unique times for the specified scan number, observation ID, and
# array ID. If perspw=True, the returned data structure is a dictionary
# that has keys representing zero-based spectral window IDs and values
# representing the unique values of the TIME column corrsponding to the
# specified scan and that corresponding spectral window ID. If False, an
# array of unique values from the TIME column for the specified scan is
# returned; there is no separation into spectral window IDs.
#
# Parameters
#
# scan : undefined = -1
#
# Scan number for which to return the times.
#
# obsid : undefined = -1
#
# Observation ID. A negative value indicates all observation IDs should be
# used.
#
# arrayid : undefined = -1
#
# Array ID. A negative value indicates all array IDs should be used.
#
# perspw : undefined = false
#
# Return output dictionary with keys representing spectral window IDs
# (True), or an array of all times (False).
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the times associated with scan number 10, all
# obsids, all arrayids. times = msmd.timesforscan(10) msmd.done()
#
# function **timesforscans**
#
# Get an array of the unique times for the specified scan numbers,
# observation ID, and array ID.
#
# Parameters
#
# scans : any = -1
#
# Scan number(s) for which to return the times.
#
# obsid : undefined = -1
#
# Observation ID. A negative value indicates all observation IDs should be
# used.
#
# arrayid : undefined = -1
#
# Array ID. A negative value indicates all array IDs should be used.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the times associated with scan numbers 10 and
# 20, all obsids, all arrayids times = msmd.timesforscans(\[10,20\])
# msmd.done()
#
# undefined **timesforspws**
#
# Get the unique times corresponding to the specified spectral window(s).
# The input indicates the spws for which times are to be retrieved, and
# can be a single integer or an array of integers. If a single,
# non-negative integer, an array of unique times associated with that
# spectral window are returned. Otherwise, a dictionary of times
# associated with the specified spectral windows are returned, with the
# spws (as strings) as the keys and the times as the values. A negative
# integer will cause a dictionary of all spws and their associated times
# to be returned.
#
# Parameters
#
# spw : any = -1
#
# Zero-based spectral window ID(s). A negative integer will cause the all
# the times for all spws to be returned.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the times associated with spws 10 and 20 times
# = msmd.timesforspws(\[10,20\]) \

# %% [markdown]
# ## print the times for spw 10 print
# times\["10"\] msmd.done()
#
# function **transitions**
#
# Get the spectral transitions from the SOURCE table for the specified
# source and spectral window. The return value will be an array of
# transitions if the transitions are defined for the specified inputs, or
# False if they do not.
#
# Parameters
#
# sourceid : undefined = 0
#
# Zero-based source ID (from the SOURCE::SOURCE_ID column).
#
# spw : undefined = 0
#
# Zero-based spectral window ID.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the transitions for source ID 2 and spw ID 20
# reffreq = msmd.transitions(2, 20) msmd.done()
#
# function **wvrspws**
#
# Get an array of spectral window IDs used for WVR. These are windows that
# have 4 channels. If complement is True, return the complement set
# instead (all non-wvr spw IDs). WVR windows are identified using the
# algorithm 1. check for water vapor radiometer (WVR) spectral windows
# using the spectral window name "WVR\#NOMINAL" and report these. 2. If no
# SPWs match that string, then the names are checked for "WVR" and are
# reported instead.
#
# Parameters
#
# complement : undefined = false
#
# If True, return all non-wvr spws.
#
# Example
#
# msmd.open("my.ms") \

# %% [markdown]
# ## get the spectral window IDs used for WVR. wvr_spws
# = msmd.wvrspws() msmd.done()
