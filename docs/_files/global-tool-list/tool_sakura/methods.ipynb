# %% [markdown]
# # Methods
#
# task applycal parameters
#
# &nbsp;
#
# constructor **sakura**
#
# This is used to construct an {\\tt sakura} tool.
#
# Parameters : None
#
# Example
#
# Manual tool construction is done this way: ssd = casac.sakura()
#
# function **initialize_sakura**
#
# This function returns True/False based on an result of initialize
#
# Parameters
#
# level : undefined = WARN
#
# Log level.
#
# Allowed Value(s)
#
# WARN ERROR INFO DEBUG
#
# Example
#
# ssd.initialize_sakura("WARN")
#
# function **cleanup_sakura**
#
# This function returns True/False based on an result of finalize
#
# Parameters : None
#
# Example
#
# ssd.cleanup_sakura()
